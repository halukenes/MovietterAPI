# %%
import re
import os
import string
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from nltk.stem.snowball import SnowballStemmer
import nltk
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
dataset_path = "./moviereviews/crime/tt0114369_reviews.csv"

reviews = pd.read_csv(dataset_path,encoding = 'utf-8')

reviews
# Out:
#                                               Reviews
# 0   The movie, "Se7en", starring Brad Pitt, Morgan...
# 1   It is a rarity for a film to be completely uns...
# 2   Seldom does a film elucidate the culpability o...
# 3   Seven's quality puts it so far beyond most of ...
# 4   Gothic, shocking, suspenseful, disturbing and ...
# 5   Rarely there has been a movie with such a good...
# 6   This movie is from start to finish a well prod...
# 7   Se7En Se7en is just one of those movies that b...
# 8   A stand out film dealing with a particularly u...
# 9   David Fincher's bleak, relentless, and ultimat...
# 10  Se7en is a very complex and deep movie, while ...
# 11  Seven is directed by David Fincher and written...
# 12  Despite clichés, and a very depressing finale,...
# 13  Somerset, (Morgan Freeman) a deeply Intellectu...
# 14  `Days from retirement' Detective Somerset is t...
# 15  This is one of those dark movies, where it's c...
# 16  After the Alien-debacle Fincher proved all the...
# 17  I love psychological thrillers and this is one...
# 18  Two cops - one young, one old - chase a serial...
# 19  After years of experiencing dull, formulaic, c...
# 20  In 1995 David Fincher released a perfectly con...
# 21  I grew up watching suspense thrillers with my ...
# 22  First off, I KNOW that I'm gonna get grief and...
# 23  "Se7en" (1995) is a true masterpiece. I have s...
# 24  (This review may contain spoilers)I'll just go...
# 25  `Se7en' is all about harsh style and gruesome ...
# 26  When audiences went to see the latest producti...
# 27  I went through these comments because I was tr...
# 28  I didn't know what I was getting into when I s...
# 29  "Se7en" (1995) Dir: David FincherThere's no ci...
# 30  I went to a friends house last night and rente...
# 31  'He is preaching
# .punishing'.Serial killing wi...
# 32  After the abysmal failure of Alien 3, David Fi...
# 33  With so many reviews on this great movie, I th...
# 34  After his calamitous experience working on his...
# 35  David Fincher's "Se7en" is one such movie that...
# 36  I won't bother with spoilers, as there are ple...
# 37  i love this film, it is the ultimate thriller ...
# 38  At first, I was a little hesitant about taking...
# 39  I finally saw this movie after seeing how high...
# 40  Spoilers herein.What a great boon these DVDs a...
# 41  I can't remember the last movie I saw that was...
# 42  The greatest thriller of all time right next t...
# 43  This story takes you where it wants you to go....
# 44  This is an outstanding movie. Morgan Freeman a...
# 45  This is by far the finest serial killer movie ...
# 46  I'm surprised this film is even listed in the ...
# 47  I didn't really hold out much hope for SEVEN ....
# 48  Bleak, gruesome, brilliant. These are a few of...
# 49  This movie is regarded as the definition of a ...

# %%
from nltk.corpus import stopwords
from pywsd.utils import lemmatize
stop_words = set(stopwords.words('english'))
stop_words.add('didnt')
stop_words.add('movie')
stop_words.add('film')
stop_words.add('could')
stop_words.add('be')
stop_words.add('even')
stop_words.add('would')

def preprocess(text):
    new_text = re.sub('<.*?>', '', text)   # remove HTML tags
    new_text = re.sub(r'[^\w\s]', ' ', new_text) # remove punc.
    new_text = re.sub(r'\d+','',new_text) # remove numbers
    new_text = new_text.lower() # lower case, .upper() for upper
    return new_text

def tokenization_w(texts):
    tokenized_texts = []
    for text in texts:
        w_token = word_tokenize(text)
        filtered_sentence = [w for w in w_token]
        tokenized_texts.append(filtered_sentence)
    return tokenized_texts

snowball = SnowballStemmer(language = 'english')
def stemming(token_array):
    stems = []
    for tokens in token_array:
        stem_words = [snowball.stem(x) for x in tokens]
        stems.append(stem_words)
    return stems

def lemmatization(stem_array):
    lemmatized = []
    for stems in stem_array:
        lemmas = [lemmatize(x) for x in stems if not x in stop_words]
        lemmatized.append(lemmas)
    return lemmatized
# Out:
# Warming up PyWSD (takes ~10 secs)... took 7.897058010101318 secs.

# %%
reviews['Reviews'] = reviews['Reviews'].apply(preprocess)

tokens = tokenization_w(reviews['Reviews'])

#stemmed = stemming(tokens)

lemmatized_data = lemmatization(tokens)

processed_data = [' '.join(list) for list in lemmatized_data]

processed_data
# Out:
# ['see star brad pitt morgan freeman gwyneth paltrow far one inventive well write cerebral film recent history blending well put together combination dark visual style intense plot development polished act remains tight focus throughout begin end never stray outwards unimportant issue resort typical hollywood clichés see uniquely suspense drama fuel need audience drawn entertain event unfold remain uncompromising shock thus satisfy initial vision director david fincher story surround hunt serial killer inspire dante alighieri seven deadly sin divine comedy set preach man impurity target victim torture pit underline sin see seemingly start typical cat mouse detective story however quickly develops sort modern myth good evil take centre stage story original count thrill level important aspect see however keep audience numerous step behind story oppose thriller become predictable bland end keep audience dark remains fresh original progress see dramatically turn tide one point audience finally get comfortable assert gloomy atmosphere thus create much fear uncertainty audience character involve conclusion audience much apart character arrive see surprise end without single clue prior occur see poetic end give away say lot people behind show afraid go grain rarity film nowadays direct brilliantly david fincher skillfully write andrew kevin walker see well craft ingeniously clever make one great film see may garner critical acclaim film silence lamb see undoubtedly influential date score',
#  'rarity completely unsettle yet unrelentingly grip david fincher story take place bleak constantly rain city never name urban decay sleaze form rampant come retirement police force detective lieutenant somerset morgan freeman tasked break replacement detective sergeant mill brad pitt leave somerset world weary illusion futility daily role play initially want nothing escape grime violence city mill hand convince go make real difference voluntarily transfer precinct bring wife city somerset move homicide come mill assign investigate first string ritual murder commit killer base crime seven deadly sin depict dante divine comedy begin see appear standard cop trail killer story difficult audience get comfortable descend along character merciless brutal world without hope inhabit left reel event unfold two detective enjoy uneasy relationship real friendship ever strike old somerset educate astute give impression emotionally burnt mill respect somerset methodical investigate get excite thought solve murder firmly believe good guy win eventually get action might evil face push men beyond limit draw heavily biblical theme certainly see similarity film seventh seal film show price good men pay fight evil unsettle truth rule book go straight window deal something diabolical boundary limit see show u world destroyed sin wasteland value minimal killer nothing contempt world see mission expose fault show everyone become fascinate twist killer motif become clearer somerset great understand actually feel degree empathy lose mill though whose level clarity never reach point previous reviewer mention begin expect unexpected whilst watch see completely agree eventually think obvious outcome situation predict opposite happen usually finale become kind predictable condition hope minor flaw though story well shockingly told director david fincher pick another script month exhaustion frustration follow completion alien apparently agree direct see one reading andrew kevin walker screenplay drawn hard hit delivery inhumanity state psychologically violent implies much camera work specially alter stock use make visual look dark unsettle possible complement well howard shore music score disturb message see put across fight evil destine pyrrhic victory regardless thing fight whatever cost choice world fine place worth fight agree second part',
#  'really hold much hope seven almost year old one frequently miss usually purpose show television always thought david fincher painfully rat best director generation claim many people patently untrue see danny boyle darren aronfsky ang lee premise inspire optimism couple mismatch police partner try track serial killer motivate seven deadly sin almost believe go watch rework vincent price camp classic horror theatre blood without funny bit go low expectation fincher do construct thriller dialogue driven sense portent dread easy perhaps easy shock audience gore startle moment instead director resists easy temptation put audience shoe detective somerset mill rare thriller audience join dot detective greatly help morgan freeman probably hollywood effective character actor point amazingly pitt spacey hold act legend short good gloomy thriller dark cinematography dark subject matter fact much understatement refresh nearly year first hit big screen remains director david fincher best work',
#  'bleak gruesome brilliant word come mind think david fincher see lesser hand concept two detective trail serial killer commit stylize murder base seven deadly sin nothing gimmick deftly craft game cat mouse pull make want turn away say call exceptionally graphic imply show fill blank spot mind eye far effective technique cheap gross route cast excellent lead inimitable morgan freeman believe freeman get oscar nod cite genre bias think silence lamb get everything kitchen sink year academy award co star brad pitt freeman hold veteran two exceptional chemistry killer whose identity reveal l ruin surprise may see brilliant brief scene pleasant risk spoil happy end filmmaking storytelling clinic one hell good',
#  'regard definition modern thriller easy see easily one suspenseful movie ever see add suspense straightforward yet grim storyline keep audience interested plot revolves around two detective william somerset david mill try solve mystery serial killer killer john doe leaf clue around unknown reason detective somerset believe killer follow seven deadly sin hence title seven see lead something unclear eventually capture reveals final victim david wife tracy thus show play game along movie see since suspenseful also quite bleak admittedly put time still great definitely worth watch old enough remember rat r whether enjoy probably find interest get']

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(processed_data))

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(bigram_mod[data_words[0]])
# Out:
# ['see', 'star', 'brad_pitt', 'morgan_freeman', 'gwyneth_paltrow', 'far', 'one', 'inventive', 'well', 'write', 'cerebral', 'film', 'recent', 'history', 'blending', 'well', 'put', 'together', 'combination', 'dark', 'visual', 'style', 'intense', 'plot', 'development', 'polished', 'act', 'remains', 'tight', 'focus', 'throughout', 'begin', 'end', 'never', 'stray', 'outwards', 'unimportant', 'issue', 'resort', 'typical', 'hollywood', 'cliches', 'see', 'uniquely', 'suspense', 'drama', 'fuel', 'need', 'audience', 'drawn', 'entertain', 'event', 'unfold', 'remain', 'uncompromising', 'shock', 'thus', 'satisfy', 'initial', 'vision', 'director', 'david', 'fincher', 'story', 'surround', 'hunt', 'serial', 'killer', 'inspire', 'dante', 'alighieri', 'seven_deadly', 'sin', 'divine', 'comedy', 'set', 'preach', 'man', 'impurity', 'target', 'victim', 'torture', 'pit', 'underline', 'sin', 'see', 'seemingly', 'start', 'typical', 'cat', 'mouse', 'detective', 'story', 'however', 'quickly', 'develops', 'sort', 'modern', 'myth', 'good', 'evil', 'take', 'centre', 'stage', 'story', 'original', 'count', 'thrill', 'level', 'important', 'aspect', 'see', 'however', 'keep', 'audience', 'numerous', 'step', 'behind', 'story', 'oppose', 'thriller', 'become', 'predictable', 'bland', 'end', 'keep', 'audience', 'dark', 'remains', 'fresh', 'original', 'progress', 'see', 'dramatically', 'turn', 'tide', 'one', 'point', 'audience', 'finally', 'get', 'comfortable', 'assert', 'gloomy', 'atmosphere', 'thus', 'create', 'much', 'fear', 'uncertainty', 'audience', 'character', 'involve', 'conclusion', 'audience', 'much', 'apart', 'character', 'arrive', 'see', 'surprise', 'end', 'without', 'single', 'clue', 'prior', 'occur', 'see', 'poetic', 'end', 'give', 'away', 'say', 'lot', 'people', 'behind', 'show', 'afraid', 'go', 'grain', 'rarity', 'film', 'nowadays', 'direct', 'brilliantly', 'david', 'fincher', 'skillfully', 'write', 'andrew_kevin', 'walker', 'see', 'well', 'craft', 'ingeniously', 'clever', 'make', 'one', 'great', 'film', 'see', 'may', 'garner', 'critical', 'acclaim', 'film', 'silence_lamb', 'see', 'undoubtedly', 'influential', 'date', 'score']

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# Form Bigrams
data_words_bigrams = make_trigrams(data_words)

data_words_bigrams
# Out:
# [['see',
#   'star',
#   'brad_pitt',
#   'morgan_freeman',
#   'gwyneth_paltrow',
#   'far',
#   'one',
#   'inventive',
#   'well',
#   'write',
#   'cerebral',
#   'film',
#   'recent',
#   'history',
#   'blending',
#   'well',
#   'put',
#   'together',
#   'combination',
#   'dark',
#   'visual',
#   'style',
#   'intense',
#   'plot',
#   'development',
#   'polished',
#   'act',
#   'remains',
#   'tight',
#   'focus',
#   'throughout',
#   'begin',
#   'end',
#   'never',
#   'stray',
#   'outwards',
#   'unimportant',
#   'issue',
#   'resort',
#   'typical',
#   'hollywood',
#   'cliches',
#   'see',
#   'uniquely',
#   'suspense',
#   'drama',
#   'fuel',
#   'need',
#   'audience',
#   'drawn',
#   'entertain',
#   'event',
#   'unfold',
#   'remain',
#   'uncompromising',
#   'shock',
#   'thus',
#   'satisfy',
#   'initial',
#   'vision',
#   'director',
#   'david',
#   'fincher',
#   'story',
#   'surround',
#   'hunt',
#   'serial',
#   'killer',
#   'inspire',
#   'dante',
#   'alighieri',
#   'seven_deadly_sin',
#   'divine',
#   'comedy',
#   'set',
#   'preach',
#   'man',
#   'impurity',
#   'target',
#   'victim',
#   'torture',
#   'pit',
#   'underline',
#   'sin',
#   'see',
#   'seemingly',
#   'start',
#   'typical',
#   'cat',
#   'mouse',
#   'detective',
#   'story',
#   'however',
#   'quickly',
#   'develops',
#   'sort',
#   'modern',
#   'myth',
#   'good',
#   'evil',
#   'take',
#   'centre',
#   'stage',
#   'story',
#   'original',
#   'count',
#   'thrill',
#   'level',
#   'important',
#   'aspect',
#   'see',
#   'however',
#   'keep',
#   'audience',
#   'numerous',
#   'step',
#   'behind',
#   'story',
#   'oppose',
#   'thriller',
#   'become',
#   'predictable',
#   'bland',
#   'end',
#   'keep',
#   'audience',
#   'dark',
#   'remains',
#   'fresh',
#   'original',
#   'progress',
#   'see',
#   'dramatically',
#   'turn',
#   'tide',
#   'one',
#   'point',
#   'audience',
#   'finally',
#   'get',
#   'comfortable',
#   'assert',
#   'gloomy',
#   'atmosphere',
#   'thus',
#   'create',
#   'much',
#   'fear',
#   'uncertainty',
#   'audience',
#   'character',
#   'involve',
#   'conclusion',
#   'audience',
#   'much',
#   'apart',
#   'character',
#   'arrive',
#   'see',
#   'surprise',
#   'end',
#   'without',
#   'single',
#   'clue',
#   'prior',
#   'occur',
#   'see',
#   'poetic',
#   'end',
#   'give',
#   'away',
#   'say',
#   'lot',
#   'people',
#   'behind',
#   'show',
#   'afraid',
#   'go',
#   'grain',
#   'rarity',
#   'film',
#   'nowadays',
#   'direct',
#   'brilliantly',
#   'david',
#   'fincher',
#   'skillfully',
#   'write',
#   'andrew_kevin_walker',
#   'see',
#   'well',
#   'craft',
#   'ingeniously',
#   'clever',
#   'make',
#   'one',
#   'great',
#   'film',
#   'see',
#   'may',
#   'garner',
#   'critical',
#   'acclaim',
#   'film',
#   'silence_lamb',
#   'see',
#   'undoubtedly',
#   'influential',
#   'date',
#   'score'],
#  ['rarity',
#   'completely',
#   'unsettle',
#   'yet',
#   'unrelentingly',
#   'grip',
#   'david',
#   'fincher',
#   'story',
#   'take',
#   'place',
#   'bleak',
#   'constantly',
#   'rain',
#   'city',
#   'never',
#   'name',
#   'urban',
#   'decay',
#   'sleaze',
#   'form',
#   'rampant',
#   'come',
#   'retirement',
#   'police',
#   'force',
#   'detective',
#   'lieutenant',
#   'somerset',
#   'morgan_freeman',
#   'tasked',
#   'break',
#   'replacement',
#   'detective',
#   'sergeant',
#   'mill',
#   'brad_pitt',
#   'leave',
#   'somerset',
#   'world',
#   'weary',
#   'illusion',
#   'futility',
#   'daily',
#   'role',
#   'play',
#   'initially',
#   'want',
#   'nothing',
#   'escape',
#   'grime',
#   'violence',
#   'city',
#   'mill',
#   'hand',
#   'convince',
#   'go',
#   'make',
#   'real',
#   'difference',
#   'voluntarily',
#   'transfer',
#   'precinct',
#   'bring',
#   'wife',
#   'city',
#   'somerset',
#   'move',
#   'homicide',
#   'come',
#   'mill',
#   'assign',
#   'investigate',
#   'first',
#   'string',
#   'ritual',
#   'murder',
#   'commit',
#   'killer',
#   'base',
#   'crime',
#   'seven_deadly_sin',
#   'depict',
#   'dante',
#   'divine',
#   'comedy',
#   'begin',
#   'see',
#   'appear',
#   'standard',
#   'cop',
#   'trail',
#   'killer',
#   'story',
#   'difficult',
#   'audience',
#   'get',
#   'comfortable',
#   'descend',
#   'along',
#   'character',
#   'merciless',
#   'brutal',
#   'world',
#   'without',
#   'hope',
#   'inhabit',
#   'left',
#   'reel',
#   'event',
#   'unfold',
#   'two',
#   'detective',
#   'enjoy',
#   'uneasy',
#   'relationship',
#   'real',
#   'friendship',
#   'ever',
#   'strike',
#   'old',
#   'somerset',
#   'educate',
#   'astute',
#   'give',
#   'impression',
#   'emotionally',
#   'burnt',
#   'mill',
#   'respect',
#   'somerset',
#   'methodical',
#   'investigate',
#   'get',
#   'excite',
#   'thought',
#   'solve',
#   'murder',
#   'firmly',
#   'believe',
#   'good',
#   'guy',
#   'win',
#   'eventually',
#   'get',
#   'action',
#   'might',
#   'evil',
#   'face',
#   'push',
#   'men',
#   'beyond',
#   'limit',
#   'draw',
#   'heavily',
#   'biblical',
#   'theme',
#   'certainly',
#   'see',
#   'similarity',
#   'film',
#   'seventh',
#   'seal',
#   'film',
#   'show',
#   'price',
#   'good',
#   'men',
#   'pay',
#   'fight',
#   'evil',
#   'unsettle',
#   'truth',
#   'rule',
#   'book',
#   'go',
#   'straight',
#   'window',
#   'deal',
#   'something',
#   'diabolical',
#   'boundary',
#   'limit',
#   'see',
#   'show',
#   'world',
#   'destroyed',
#   'sin',
#   'wasteland',
#   'value',
#   'minimal',
#   'killer',
#   'nothing',
#   'contempt',
#   'world',
#   'see',
#   'mission',
#   'expose',
#   'fault',
#   'show',
#   'everyone',
#   'become',
#   'fascinate',
#   'twist',
#   'killer',
#   'motif',
#   'become',
#   'clearer',
#   'somerset',
#   'great',
#   'understand',
#   'actually',
#   'feel',
#   'degree',
#   'empathy',
#   'lose',
#   'mill',
#   'though',
#   'whose',
#   'level',
#   'clarity',
#   'never',
#   'reach',
#   'point',
#   'previous',
#   'reviewer',
#   'mention',
#   'begin',
#   'expect',
#   'unexpected',
#   'whilst',
#   'watch',
#   'see',
#   'completely',
#   'agree',
#   'eventually',
#   'think',
#   'obvious',
#   'outcome',
#   'situation',
#   'predict',
#   'opposite',
#   'happen',
#   'usually',
#   'finale',
#   'become',
#   'kind',
#   'predictable',
#   'condition',
#   'hope',
#   'minor',
#   'flaw',
#   'though',
#   'story',
#   'well',
#   'shockingly',
#   'told',
#   'director',
#   'david',
#   'fincher',
#   'pick',
#   'another',
#   'script',
#   'month',
#   'exhaustion',
#   'frustration',
#   'follow',
#   'completion',
#   'alien',
#   'apparently',
#   'agree',
#   'direct',
#   'see',
#   'one',
#   'reading',
#   'andrew_kevin_walker',
#   'screenplay',
#   'drawn',
#   'hard',
#   'hit',
#   'delivery',
#   'inhumanity',
#   'state',
#   'psychologically',
#   'violent',
#   'implies',
#   'much',
#   'camera',
#   'work',
#   'specially',
#   'alter',
#   'stock',
#   'use',
#   'make',
#   'visual',
#   'look',
#   'dark',
#   'unsettle',
#   'possible',
#   'complement',
#   'well',
#   'howard',
#   'shore',
#   'music',
#   'score',
#   'disturb',
#   'message',
#   'see',
#   'put',
#   'across',
#   'fight',
#   'evil',
#   'destine',
#   'pyrrhic',
#   'victory',
#   'regardless',
#   'thing',
#   'fight',
#   'whatever',
#   'cost',
#   'choice',
#   'world',
#   'fine',
#   'place',
#   'worth',
#   'fight',
#   'agree',
#   'second',
#   'part'],
#  ['seldom',
#   'elucidate',
#   'culpability',
#   'culture',
#   'society',
#   'mayhem',
#   'madness',
#   'often',
#   'find',
#   'everyday',
#   'life',
#   'accord',
#   'see',
#   'culture',
#   'drift',
#   'darkness',
#   'mouthpiece',
#   'thematic',
#   'undercurrent',
#   'somerset',
#   'literate',
#   'man',
#   'also',
#   'happens',
#   'detective',
#   'man',
#   'read',
#   'clue',
#   'go',
#   'happy',
#   'end',
#   'dante',
#   'inferno',
#   'equal',
#   'aplomb',
#   'provide',
#   'final',
#   'thematic',
#   'statement',
#   'quote',
#   'hemingway',
#   'quirkiness',
#   'perhaps',
#   'outgrowth',
#   'brilliant',
#   'mind',
#   'bad',
#   'prophet',
#   'seer',
#   'old',
#   'harbinger',
#   'biblical',
#   'insight',
#   'other',
#   'always',
#   'find',
#   'kooky',
#   'offbeat',
#   'well',
#   'love',
#   'cynical',
#   'pessimistic',
#   'outlook',
#   'consume',
#   'motivation',
#   'retire',
#   'get',
#   'town',
#   'however',
#   'end',
#   'becomes',
#   'clear',
#   'somerset',
#   'see',
#   'dark',
#   'world',
#   'prophet',
#   'particular',
#   'clarity',
#   'left',
#   'partner',
#   'mill',
#   'find',
#   'hard',
#   'way',
#   'work',
#   'reinforce',
#   'world',
#   'somerset',
#   'see',
#   'astound',
#   'mise',
#   'en',
#   'scene',
#   'disturb',
#   'noir',
#   'set',
#   'developed',
#   'director',
#   'david',
#   'fincher',
#   'cinematographer',
#   'darius',
#   'khondji',
#   'flashlight',
#   'barely',
#   'illuminate',
#   'slimy',
#   'wall',
#   'roach',
#   'infest',
#   'tenement',
#   'one',
#   'victim',
#   'dark',
#   'bedroom',
#   'another',
#   'rain',
#   'pours',
#   'bucket',
#   'bird',
#   'eye',
#   'view',
#   'shot',
#   'downtown',
#   'city',
#   'never',
#   'name',
#   'generic',
#   'everyman',
#   'kind',
#   'place',
#   'show',
#   'dingy',
#   'sooty',
#   'rooftop',
#   'grimy',
#   'street',
#   'closing',
#   'scene',
#   'bright',
#   'sunlight',
#   'serf',
#   'ironic',
#   'counterpoint',
#   'see',
#   'happen',
#   'somerset',
#   'vision',
#   'inhabit',
#   'described',
#   'find',
#   'surprising',
#   'fellow',
#   'traveler',
#   'partner',
#   'elusive',
#   'killer',
#   'john_doe',
#   'doe',
#   'share',
#   'vision',
#   'provide',
#   'unsettle',
#   'echo',
#   'rumbling',
#   'teaching',
#   'somerset',
#   'one',
#   'look',
#   'life',
#   'somerset',
#   'lens',
#   'one',
#   'must',
#   'admit',
#   'john_doe',
#   'valid',
#   'point',
#   'somerset',
#   'arrive',
#   'conclusion',
#   'difference',
#   'respond',
#   'somerset',
#   'longs',
#   'escape',
#   'otherworldly',
#   'realm',
#   'country',
#   'doe',
#   'take',
#   'action',
#   'though',
#   'grip',
#   'fast',
#   'move',
#   'action',
#   'hold',
#   'interest',
#   'working',
#   'horror',
#   'mystery',
#   'stark',
#   'noir',
#   'detective',
#   'piece',
#   'except',
#   'one',
#   'tense',
#   'pursuit',
#   'hall',
#   'alley',
#   'pour',
#   'rain',
#   'well',
#   'bit',
#   'end',
#   'action',
#   'surprisingly',
#   'little',
#   'violence',
#   'see',
#   'murder',
#   'save',
#   'two',
#   'fact',
#   'crime',
#   'scene',
#   'make',
#   'final',
#   'act',
#   'much',
#   'suspenseful',
#   'tight',
#   'element',
#   'within',
#   'dialogue',
#   'action',
#   'light',
#   'set',
#   'tend',
#   'reinforce',
#   'one',
#   'another',
#   'paint',
#   'solid',
#   'picture',
#   'perverse',
#   'logic',
#   'make',
#   'final',
#   'seventh',
#   'sin',
#   'complete',
#   'perfectly',
#   'circle',
#   'event',
#   'begin',
#   'first'],
#  ['seven',
#   'quality',
#   'put',
#   'far',
#   'beyond',
#   'cop',
#   'trail',
#   'derange',
#   'killer',
#   'genre',
#   'come',
#   'true',
#   'jewel',
#   'cinema',
#   'everything',
#   'seven',
#   'perfect',
#   'art',
#   'capture',
#   'bright',
#   'spot',
#   'star',
#   'work',
#   'brad_pitt',
#   'never',
#   'get',
#   'credit',
#   'deserves',
#   'act',
#   'pretty',
#   'boy',
#   'press',
#   'lot',
#   'interested',
#   'jennifer',
#   'shame',
#   'talented',
#   'actor',
#   'afraid',
#   'take',
#   'chance',
#   'role',
#   'pick',
#   'character',
#   'play',
#   'quite',
#   'rare',
#   'list',
#   'world',
#   'morgan_freeman',
#   'great',
#   'actor',
#   'always',
#   'count',
#   'best',
#   'play',
#   'wise',
#   'veteran',
#   'see',
#   'kevin_spacey',
#   'another',
#   'great',
#   'actor',
#   'great',
#   'range',
#   'really',
#   'put',
#   'life',
#   'personality',
#   'character',
#   'real',
#   'talent',
#   'exclude',
#   'actor',
#   'brought',
#   'life',
#   'director',
#   'david',
#   'fincher',
#   'writer',
#   'andrew_kevin_walker',
#   'fincher',
#   'talent',
#   'make',
#   'visually',
#   'stun',
#   'well',
#   'know',
#   'often',
#   'brings',
#   'dark',
#   'patina',
#   'work',
#   'andrew_kevin_walker',
#   'must',
#   'incredible',
#   'demon',
#   'living',
#   'inside',
#   'either',
#   'one',
#   'hell',
#   'imagination',
#   'bring',
#   'intricate',
#   'story',
#   'seven',
#   'plan',
#   'john_doe',
#   'life',
#   'john_doe',
#   'plan',
#   'really',
#   'twist',
#   'spoil',
#   'suffice',
#   'say',
#   'never',
#   'see',
#   'evil',
#   'complicate',
#   'plan',
#   'since',
#   'cinematography',
#   'dark',
#   'beautiful',
#   'throughout',
#   'either',
#   'night',
#   'rain',
#   'except',
#   'two',
#   'brief',
#   'moment',
#   'emotional',
#   'keep',
#   'caught',
#   'happen',
#   'understand',
#   'sympathize',
#   'john_doe',
#   'think',
#   'mad',
#   'killer',
#   'must',
#   'stop',
#   'bottom',
#   'line',
#   'opportunity',
#   'see',
#   'seven',
#   'yet',
#   'must',
#   'least',
#   'rent',
#   'damn',
#   'good',
#   'know',
#   'like',
#   'reason',
#   'damn',
#   'fragile',
#   'take',
#   'something',
#   'hardcore'],
#  ['gothic',
#   'shock',
#   'suspenseful',
#   'disturb',
#   'clever',
#   'seven',
#   'marked',
#   'new',
#   'begin',
#   'director',
#   'david',
#   'fincher',
#   'career',
#   'dark',
#   'tale',
#   'murder',
#   'crime',
#   'revolves',
#   'around',
#   'two',
#   'detective',
#   'present',
#   'new',
#   'york',
#   'city',
#   'played',
#   'two',
#   'brilliant',
#   'actor',
#   'brad_pitt',
#   'morgan_freeman',
#   'pair',
#   'together',
#   'solve',
#   'puzzle',
#   'murder',
#   'hand',
#   'man',
#   'kill',
#   'regard',
#   'seven_deadly_sin',
#   'actor',
#   'displayed',
#   'strike',
#   'performance',
#   'sharp',
#   'realistic',
#   'sometimes',
#   'remind',
#   'act',
#   'david',
#   'fincher',
#   'masterpiece',
#   'really',
#   'give',
#   'opportunity',
#   'lifetime',
#   'maybe',
#   'one',
#   'wish',
#   'share',
#   'see',
#   'experience',
#   'glimpse',
#   'horror',
#   'world',
#   'fill',
#   'small',
#   'piece',
#   'mind',
#   'man',
#   'prey',
#   'never',
#   'meet',
#   'brad_pitt',
#   'successfully',
#   'prof',
#   'pretty',
#   'face',
#   'screen',
#   'sink',
#   'character',
#   'well',
#   'walk',
#   'finish',
#   'classify',
#   'pretty',
#   'darn',
#   'good',
#   'actor',
#   'expect',
#   'anything',
#   'els',
#   'morgan_freeman',
#   'perfectly',
#   'obvious',
#   'guy',
#   'born',
#   'play',
#   'role',
#   'smart',
#   'detective',
#   'david',
#   'fincher',
#   'timeless',
#   'direct',
#   'memorable',
#   'film',
#   'capture',
#   'good',
#   'offer',
#   'undoubtedly',
#   'leave',
#   'shock',
#   'beg',
#   'film',
#   'like',
#   'seven',
#   'step',
#   'harsh',
#   'reality',
#   'life',
#   'realistic',
#   'portrayal',
#   'two',
#   'detective',
#   'investigation',
#   'un',
#   'describable',
#   'horrific',
#   'world',
#   'murder',
#   'darkest',
#   'realm',
#   'human',
#   'soul',
#   'prey',
#   'classic',
#   'memorable',
#   'work',
#   'mr',
#   'fincher',
#   'future',
#   'director',
#   'intent',
#   'make',
#   'gothic',
#   'psychological',
#   'thriller',
#   'make',
#   'sure',
#   'sit',
#   'watch',
#   'seven',
#   'pen',
#   'paper',
#   'ready',
#   'take',
#   'note'],
#  ['rarely',
#   'good',
#   'dark',
#   'chill',
#   'atmosphere',
#   'see',
#   'horror',
#   'thriller',
#   'see',
#   'unique',
#   'many',
#   'way',
#   'movie',
#   'mood',
#   'already',
#   'set',
#   'right',
#   'begin',
#   'start',
#   'dark',
#   'intense',
#   'chill',
#   'mysterious',
#   'mood',
#   'present',
#   'throughout',
#   'entire',
#   'depress',
#   'watch',
#   'mean',
#   'positive',
#   'way',
#   'meaning',
#   'word',
#   'mood',
#   'set',
#   'good',
#   'camera',
#   'work',
#   'light',
#   'well',
#   'say',
#   'lack',
#   'music',
#   'acclaim',
#   'composer',
#   'howard',
#   'shore',
#   'also',
#   'add',
#   'chill',
#   'atmosphere',
#   'unlike',
#   'many',
#   'movie',
#   'genre',
#   'slow',
#   'pace',
#   'take',
#   'time',
#   'develop',
#   'character',
#   'without',
#   'fall',
#   'obvious',
#   'cliche',
#   'two',
#   'main',
#   'character',
#   'played',
#   'morgan_freeman',
#   'brad_pitt',
#   'present',
#   'unlikely',
#   'police',
#   'couple',
#   'different',
#   'many',
#   'way',
#   'way',
#   'also',
#   'make',
#   'great',
#   'couple',
#   'brad_pitt',
#   'opportunity',
#   'play',
#   'pretty',
#   'boy',
#   'success',
#   'kevin_spacey',
#   'truly',
#   'play',
#   'bone',
#   'chill',
#   'character',
#   'almost',
#   'legendary',
#   'chill',
#   'hannibal',
#   'lecter',
#   'much',
#   'like',
#   'see',
#   'two',
#   'put',
#   'room',
#   'see',
#   'make',
#   'alive',
#   'great',
#   'see',
#   'lee',
#   'emrey',
#   'police',
#   'captain',
#   'fill',
#   'truly',
#   'gross',
#   'sicken',
#   'horrify',
#   'scene',
#   'seriously',
#   'kid',
#   'stuff',
#   'sicken',
#   'murder',
#   'ever',
#   'see',
#   'feature',
#   'gross',
#   'scene',
#   'good',
#   'also',
#   'scene',
#   'make',
#   'lot',
#   'beauty',
#   'profession',
#   'library',
#   'scene',
#   'dark',
#   'chill',
#   'never',
#   'forget',
#   'also',
#   'thanks',
#   'end',
#   'spoil',
#   'real',
#   'must',
#   'see'],
#  ['start',
#   'finish',
#   'well',
#   'produce',
#   'direct',
#   'performance',
#   'outstanding',
#   'brad_pitt',
#   'make',
#   'role',
#   'stand',
#   'performance',
#   'put',
#   'versatile',
#   'act',
#   'skill',
#   'interpretation',
#   'detective',
#   'david',
#   'mill',
#   'morgan_freeman',
#   'well',
#   'cast',
#   'brooding',
#   'act',
#   'style',
#   'fit',
#   'character',
#   'detective',
#   'william',
#   'somerset',
#   'like',
#   'glove',
#   'gwyneth_paltrow',
#   'give',
#   'best',
#   'performance',
#   'ever',
#   'role',
#   'brad_pitt',
#   'supportive',
#   'wife',
#   'lover',
#   'tracy',
#   'mill',
#   'course',
#   'kevin_spacey',
#   'play',
#   'diabolical',
#   'yet',
#   'misunderstood',
#   'serial',
#   'killer',
#   'suspenseful',
#   'part',
#   'excite',
#   'pseudo',
#   'noir',
#   'quality',
#   'really',
#   'fit',
#   'well',
#   'content',
#   'serial',
#   'kill',
#   'philosophical',
#   'moment',
#   'anyone',
#   'think',
#   'lot',
#   'state',
#   'world',
#   'today',
#   'appreciate',
#   'make',
#   'subtle',
#   'moral',
#   'judgement',
#   'without',
#   'insult',
#   'belief',
#   'viewer',
#   'may',
#   'also',
#   'generates',
#   'debate',
#   'post',
#   'coffee',
#   'drink',
#   'gathering',
#   'andrew_kevin_walker',
#   'screenplay',
#   'take',
#   'subject',
#   'seven_deadly_sin',
#   'really',
#   'put',
#   'great',
#   'new',
#   'twist',
#   'theme',
#   'writer',
#   'really',
#   'appreciate',
#   'depth',
#   'go',
#   'idea',
#   'give',
#   'enough',
#   'information',
#   'entertain',
#   'inform',
#   'yet',
#   'bombard',
#   'make',
#   'bore',
#   'much',
#   'philosophy',
#   'respect',
#   'preach',
#   'special',
#   'meaning',
#   'though',
#   'moral',
#   'statement',
#   'still',
#   'maintain',
#   'enjoy',
#   'many',
#   'level',
#   'really',
#   'enjoy',
#   'third',
#   'act',
#   'one',
#   'best',
#   'piece',
#   'storytelling',
#   'scriptwriting',
#   'ever',
#   'outstanding',
#   'performance',
#   'everyone',
#   'involve',
#   'yes',
#   'course',
#   'david',
#   'fincher',
#   'wonderful',
#   'job',
#   'say'],
#  ['see',
#   'see',
#   'one',
#   'movie',
#   'burrow',
#   'deep',
#   'skin',
#   'fester',
#   'director',
#   'david',
#   'fincher',
#   'screenwriter',
#   'andrew_kevin_walker',
#   'create',
#   'bleak',
#   'desolate',
#   'world',
#   'real',
#   'hero',
#   'sinner',
#   'uncompromising',
#   'story',
#   'filthy',
#   'grainy',
#   'visual',
#   'terrific',
#   'performance',
#   'make',
#   'see',
#   'modern',
#   'classic',
#   'det',
#   'william',
#   'sommerset',
#   'morgan_freeman',
#   'see',
#   'human',
#   'spirit',
#   'bad',
#   'throughout',
#   'year',
#   'police',
#   'service',
#   'finally',
#   'realises',
#   'enough',
#   'horror',
#   'world',
#   'becomes',
#   'ready',
#   'retirement',
#   'david',
#   'mill',
#   'brad_pitt',
#   'brash',
#   'hot',
#   'head',
#   'rookie',
#   'cop',
#   'believe',
#   'big',
#   'break',
#   'lie',
#   'murky',
#   'seedy',
#   'unnamed',
#   'metropolis',
#   'amidst',
#   'cynicism',
#   'sommerset',
#   'take',
#   'mill',
#   'partner',
#   'last',
#   'day',
#   'two',
#   'murder',
#   'occur',
#   'within',
#   'two',
#   'day',
#   'duo',
#   'realize',
#   'serial',
#   'killer',
#   'murder',
#   'victim',
#   'accordance',
#   'seven_deadly_sin',
#   'gluttony_greed',
#   'sloth',
#   'lust',
#   'pride',
#   'envy',
#   'wrath',
#   'follow',
#   'terrify',
#   'disturb',
#   'story',
#   'dark',
#   'side',
#   'human',
#   'nature',
#   'fincher',
#   'noir',
#   'york',
#   'endless',
#   'rain',
#   'rain',
#   'fails',
#   'wash',
#   'quote',
#   'travis',
#   'bickle',
#   'filth',
#   'street',
#   'harsh',
#   'look',
#   'urban',
#   'life',
#   'decency',
#   'rarity',
#   'along',
#   'cinematographer',
#   'darius',
#   'khondji',
#   'paint',
#   'screen',
#   'dark',
#   'grey',
#   'black',
#   'yellow',
#   'hint',
#   'rot',
#   'core',
#   'environment',
#   'freeman',
#   'give',
#   'complex',
#   'performance',
#   'moral',
#   'core',
#   'detective',
#   'grown',
#   'weary',
#   'apathy',
#   'slightly',
#   'suggests',
#   'understand',
#   'despicable',
#   'killer',
#   'note',
#   'kevin_spacey',
#   'delivers',
#   'chill',
#   'portrayal',
#   'killer',
#   'blankly',
#   'human',
#   'face',
#   'disturb',
#   'conviction',
#   'writer',
#   'walker',
#   'write',
#   'cop',
#   'genre',
#   'impeccable',
#   'substance',
#   'rather',
#   'whodunit',
#   'action',
#   'give',
#   'birth',
#   'story',
#   'poke',
#   'prod',
#   'psychic',
#   'force',
#   'confront',
#   'question',
#   'next',
#   'time',
#   'eat',
#   'much',
#   'take',
#   'much',
#   'time',
#   'gel',
#   'hair',
#   'lash',
#   'road',
#   'rage',
#   'question',
#   'day',
#   'day',
#   'apathy',
#   'ignorance',
#   'savagery',
#   'human',
#   'existence',
#   'time',
#   'war',
#   'poverty',
#   'cynicism',
#   'importantly',
#   'sin'],
#  ['stand',
#   'deal',
#   'particularly',
#   'unpleasant',
#   'serial',
#   'killer',
#   'see',
#   'along',
#   'silence_lamb',
#   'something',
#   'milestone',
#   'genre',
#   'intelligent',
#   'script',
#   'admirable',
#   'actor',
#   'include',
#   'excellent',
#   'morgan_freeman',
#   'prad',
#   'pitt',
#   'gwenth',
#   'paltrow',
#   'kevin_spacey',
#   'cinema',
#   'noir',
#   'style',
#   'grisly',
#   'murder',
#   'represent',
#   'seven_deadly_sin',
#   'performance',
#   'however',
#   'lift',
#   'average',
#   'morgan_freeman',
#   'old',
#   'world',
#   'wise',
#   'detective',
#   'pitt',
#   'almost',
#   'manic',
#   'young',
#   'enthusiastic',
#   'sidekick',
#   'poltrow',
#   'play',
#   'wife',
#   'fine',
#   'degree',
#   'sensitivity',
#   'spacey',
#   'usual',
#   'brilliant',
#   'psycho',
#   'routine',
#   'pivotal',
#   'scene',
#   'freeman',
#   'paltrow',
#   'cafe',
#   'show',
#   'depth',
#   'performance',
#   'believable',
#   'character',
#   'dark',
#   'disturb',
#   'world',
#   'wherein',
#   'always',
#   'seem',
#   'rain',
#   'effective',
#   'thriller',
#   'tight',
#   'direction',
#   'atmospheric',
#   'photography'],
#  ['david',
#   'fincher',
#   'bleak',
#   'relentless',
#   'ultimately',
#   'terrify',
#   'crime',
#   'thriller',
#   'seven',
#   'transcends',
#   'film',
#   'genre',
#   'incredible',
#   'plot',
#   'sort',
#   'hitchcock',
#   'might',
#   'employ',
#   'alive',
#   'make',
#   'film',
#   'scald',
#   'intelligence',
#   'small',
#   'handful',
#   'minor',
#   'flaw',
#   'overly',
#   'familiar',
#   'retire',
#   'cop',
#   'young',
#   'cop',
#   'pair',
#   'awful',
#   'take',
#   'case',
#   'cliche',
#   'seemingly',
#   'require',
#   'genre',
#   'one',
#   'giant',
#   'lapse',
#   'logic',
#   'downward',
#   'spiral',
#   'toward',
#   'conclusion',
#   'reveal',
#   'without',
#   'ruin',
#   'script',
#   'gruesome',
#   'surprise',
#   'seven',
#   'typically',
#   'keep',
#   'viewer',
#   'imprison',
#   'seat',
#   'combination',
#   'morbid',
#   'fascination',
#   'abject',
#   'fear',
#   'despite',
#   'attempt',
#   'studio',
#   'executive',
#   'alter',
#   'andrew_kevin_walker',
#   'end',
#   'filmmaking',
#   'team',
#   'prevail',
#   'audience',
#   'experienced',
#   'rare',
#   'treat',
#   'mainstream',
#   'cinema',
#   'uncompromising',
#   'vision'],
#  ['see',
#   'complex',
#   'deep',
#   'also',
#   'quite',
#   'disturb',
#   'andrew_kevin_walker',
#   'create',
#   'one',
#   'original',
#   'spec',
#   'screenplay',
#   'time',
#   'kind',
#   'story',
#   'traditionally',
#   'use',
#   'write',
#   'sample',
#   'actually',
#   'make',
#   'creative',
#   'team',
#   'director',
#   'david',
#   'fincher',
#   'believe',
#   'extremely',
#   'dark',
#   'uncompromising',
#   'story',
#   'make',
#   'way',
#   'walker',
#   'write',
#   'story',
#   'revolves',
#   'around',
#   'two',
#   'extremely',
#   'well',
#   'drawn',
#   'character',
#   'david',
#   'mill',
#   'brad_pitt',
#   'william',
#   'somerset',
#   'morgan_freeman',
#   'one',
#   'sense',
#   'relationship',
#   'ultimate',
#   'cliche',
#   'old',
#   'veteran',
#   'cop',
#   'pair',
#   'brash',
#   'rookie',
#   'though',
#   'mill',
#   'actually',
#   'rookie',
#   'new',
#   'unnamed',
#   'city',
#   'take',
#   'place',
#   'contrast',
#   'two',
#   'character',
#   'played',
#   'laugh',
#   'cheap',
#   'drama',
#   'real',
#   'work',
#   'moral',
#   'question',
#   'somerset',
#   'lonely',
#   'cynical',
#   'old',
#   'detective',
#   'care',
#   'people',
#   'see',
#   'much',
#   'dark',
#   'side',
#   'life',
#   'much',
#   'hope',
#   'society',
#   'mill',
#   'intelligent',
#   'somerset',
#   'kudos',
#   'pitt',
#   'willing',
#   'play',
#   'character',
#   'frequently',
#   'look',
#   'foolish',
#   'life',
#   'simplistic',
#   'belief',
#   'power',
#   'law',
#   'enforcement',
#   'change',
#   'world',
#   'throughout',
#   'two',
#   'character',
#   'struggle',
#   'conflict',
#   'human',
#   'society',
#   'basically',
#   'rotten',
#   'one',
#   'person',
#   'anything',
#   'make',
#   'difference',
#   'somerset',
#   'intelligent',
#   'well',
#   'read',
#   'man',
#   'smart',
#   'enough',
#   'recognize',
#   'truth',
#   'however',
#   'painful',
#   'mill',
#   'kind',
#   'person',
#   'never',
#   'truly',
#   'question',
#   'simple',
#   'value',
#   'raise',
#   'somerset',
#   'try',
#   'educate',
#   'try',
#   'warn',
#   'ultimately',
#   'fails',
#   'end',
#   'john_doe',
#   'serial',
#   'killer',
#   'teach',
#   'mill',
#   'extension',
#   'audience',
#   'truth',
#   'world',
#   'often',
#   'shockingly',
#   'vicious',
#   'senselessly',
#   'cruel',
#   'doe',
#   'somerset',
#   'actually',
#   'similar',
#   'view',
#   'society',
#   'world',
#   'point',
#   'somerset',
#   'still',
#   'care',
#   'fellow',
#   'human',
#   'being',
#   'doe',
#   'hate',
#   'take',
#   'rage',
#   'series',
#   'gruesome',
#   'murder',
#   'base',
#   'seven_deadly_sin',
#   'investigation',
#   'mill',
#   'somerset',
#   'undertake',
#   'doe',
#   'murder',
#   'sermon',
#   'world',
#   'serial',
#   'kill',
#   'ultimately',
#   'mill',
#   'somerset',
#   'much',
#   'try',
#   'stop',
#   'doe',
#   'killer',
#   'always',
#   'seem',
#   'least',
#   'one',
#   'step',
#   'ahead',
#   'stay',
#   'way',
#   'end',
#   'normal',
#   'hollywood',
#   'mill',
#   'somerset',
#   'win',
#   'end',
#   'catch',
#   'doe',
#   'set',
#   'world',
#   'right',
#   'andy',
#   'walker',
#   'quite',
#   'different',
#   'end',
#   'mind',
#   'fincher',
#   'team',
#   'take',
#   'shock',
#   'conclusion',
#   'way',
#   'limit',
#   'tension',
#   'drama',
#   'like',
#   'fincher',
#   'fight_club',
#   'controversial',
#   'violent',
#   'gruesome',
#   'certainly',
#   'number',
#   'gruesome',
#   'disturb',
#   'image',
#   'murder',
#   'victim',
#   'body',
#   'many',
#   'aspect',
#   'story',
#   'trouble',
#   'say',
#   'least',
#   'one',
#   'person',
#   'show',
#   'kill',
#   'screen',
#   'far',
#   'bad',
#   'happens',
#   'story',
#   'happens',
#   'viewer',
#   'imagination',
#   'unlike',
#   'film',
#   'high',
#   'level',
#   'violence',
#   'include',
#   'example',
#   'reservoir',
#   'dog',
#   'silence_lamb',
#   'genuinely',
#   'attempt',
#   'grapple',
#   'moral',
#   'implication',
#   'show',
#   'screen',
#   'direct',
#   'contrast',
#   'say',
#   'quentin',
#   'tarantino',
#   'us',
#   'extreme',
#   'violence',
#   'shock',
#   'effect',
#   'gain',
#   'notoriety',
#   'fincher',
#   'actually',
#   'show',
#   'less',
#   'violence',
#   'screen',
#   'raise',
#   'far',
#   'probe',
#   'moral',
#   'question',
#   'viewer',
#   'mind',
#   'think',
#   'contains',
#   'much',
#   'genuine',
#   'debate',
#   'discussion',
#   'among',
#   'character',
#   'crime',
#   'human',
#   'morality',
#   'one',
#   'never',
#   'become',
#   'dull',
#   'preachy',
#   'moment',
#   'finish',
#   'review',
#   'without',
#   'word',
#   'mr',
#   'fincher',
#   'extraordinary',
#   'visual',
#   'talent',
#   'man',
#   'rank',
#   'top',
#   'handful',
#   'director',
#   'time',
#   'knowledge',
#   'grasp',
#   'make',
#   'technique',
#   'everything',
#   'set',
#   'design',
#   'light',
#   'selection',
#   'stock',
#   'processing',
#   'technique',
#   'camera',
#   'movement',
#   'frame',
#   'composition',
#   'edit',
#   'work',
#   'together',
#   'create',
#   'entirely',
#   'new',
#   'level',
#   'visual',
#   'brilliance',
#   'fincher',
#   'use',
#   'technique',
#   'brings',
#   'mind',
#   'nothing',
#   'work',
#   'steven',
#   'spielberg',
#   'last',
#   'time',
#   'director',
#   'extraordinary',
#   'burst',
#   'onto',
#   'hollywood',
#   'scene',
#   'whole',
#   'generation',
#   'pass',
#   'since',
#   'new',
#   'wave',
#   'technique',
#   'tool',
#   'available',
#   'filmmaker',
#   'ninety',
#   'fincher',
#   'us',
#   'every',
#   'one',
#   'tool',
#   'utmost',
#   'technical',
#   'work',
#   'support',
#   'actor',
#   'uniformly',
#   'superb',
#   'work',
#   'every',
#   'level',
#   'andy',
#   'walker',
#   'write',
#   'mind',
#   'blowing',
#   'screenplay',
#   'must',
#   'stun',
#   'saw',
#   'finish',
#   'rock',
#   'core'],
#  ['seven',
#   'direct',
#   'david',
#   'fincher',
#   'write',
#   'andrew_kevin_walker',
#   'star',
#   'morgan_freeman',
#   'brad_pitt',
#   'gwyneth_paltrow',
#   'kevin_spacey',
#   'lee',
#   'ermey',
#   'music',
#   'score',
#   'howard',
#   'shore',
#   'cinematography',
#   'darius',
#   'khondji',
#   'unnamed',
#   'city',
#   'two',
#   'cop',
#   'trail',
#   'serial',
#   'killer',
#   'kill',
#   'victim',
#   'accord',
#   'one',
#   'seven_deadly_sin',
#   'commit',
#   'stung',
#   'studio',
#   'interference',
#   'negative',
#   'fall',
#   'regard',
#   'directorial',
#   'debut',
#   'feature',
#   'alien',
#   'david',
#   'fincher',
#   'wait',
#   'three',
#   'year',
#   'commit',
#   'project',
#   'control',
#   'result',
#   'seven',
#   'dark',
#   'masterpiece',
#   'unremitting',
#   'creep',
#   'dread',
#   'showcased',
#   'work',
#   'clinically',
#   'excellent',
#   'director',
#   'seven',
#   'experience',
#   'assault',
#   'sens',
#   'jolt',
#   'brain',
#   'trawl',
#   'dark',
#   'recess',
#   'sick',
#   'city',
#   'always',
#   'rain',
#   'darkness',
#   'hold',
#   'many',
#   'fear',
#   'boorish',
#   'slasher',
#   'psychological',
#   'discord',
#   'see',
#   'aftermath',
#   'crime',
#   'discussion',
#   'force',
#   'delve',
#   'deep',
#   'imagination',
#   'fill',
#   'blank',
#   'force',
#   'go',
#   'want',
#   'go',
#   'sense',
#   'director',
#   'somewhere',
#   'gleefully',
#   'pull',
#   'string',
#   'point',
#   'see',
#   'deadly_sin',
#   'every',
#   'street',
#   'corner',
#   'every',
#   'home',
#   'tolerate',
#   'tolerate',
#   'common',
#   'trivial',
#   'tolerate',
#   'morning',
#   'noon',
#   'night',
#   'well',
#   'anymore',
#   'set',
#   'example',
#   'do',
#   'go',
#   'puzzle',
#   'study',
#   'follow',
#   'forever',
#   'seven',
#   'much',
#   'ultimate',
#   'horror',
#   'really',
#   'anything',
#   'scary',
#   'serial',
#   'killer',
#   'smarter',
#   'cop',
#   'chase',
#   'oblivious',
#   'part',
#   'master',
#   'plan',
#   'killer',
#   'unstoppable',
#   'perpetrate',
#   'violent',
#   'crime',
#   'freeman',
#   'weary',
#   'retirement',
#   'bound',
#   'detective',
#   'somerset',
#   'say',
#   'methodical',
#   'patient',
#   'go',
#   'end',
#   'bad',
#   'cop',
#   'know',
#   'fincher',
#   'walker',
#   'stick',
#   'hand',
#   'gut',
#   'pull',
#   'last',
#   'semblance',
#   'solid',
#   'deliver',
#   'one',
#   'great',
#   'ending',
#   'modern',
#   'cinema',
#   'end',
#   'fit',
#   'grace',
#   'noir',
#   'neo',
#   'noir',
#   'smart',
#   'as',
#   'psychological',
#   'horror',
#   'across',
#   'age',
#   'view',
#   'seven',
#   'repeat',
#   'wave',
#   'bleak',
#   'emotion',
#   'come',
#   'reverse',
#   'end',
#   'credit',
#   'roll',
#   'desolation',
#   'disbelief',
#   'sadness',
#   'shock',
#   'trip',
#   'earthly',
#   'hell',
#   'psychical',
#   'sense',
#   'faultless',
#   'cast',
#   'performance',
#   'doubt',
#   'eked',
#   'know',
#   'task',
#   'master',
#   'director',
#   'photography',
#   'brilliantly',
#   'brings',
#   'light',
#   'melancholic',
#   'sheen',
#   'decay',
#   'society',
#   'howard',
#   'shore',
#   'score',
#   'crawl',
#   'speaker',
#   'cloak',
#   'body',
#   'like',
#   'evil',
#   'incubus',
#   'succubus',
#   'seven',
#   'masterpiece',
#   'unease',
#   'evil',
#   'wrung',
#   'master',
#   'director'],
#  ['despite',
#   'cliches',
#   'depress',
#   'finale',
#   'one',
#   'best',
#   'make',
#   'film',
#   'era',
#   'genre',
#   'strength',
#   'include',
#   'odd',
#   'relationship',
#   'two',
#   'lead',
#   'cop',
#   'seem',
#   'loosely',
#   'base',
#   'two',
#   'lead',
#   'cop',
#   'lethal',
#   'weapon',
#   'series',
#   'thankfully',
#   'never',
#   'play',
#   'laugh',
#   'never',
#   'really',
#   'become',
#   'buddy',
#   'young',
#   'cop',
#   'arrogant',
#   'old',
#   'cop',
#   'much',
#   'experience',
#   'young',
#   'cop',
#   'refuse',
#   'acknowledge',
#   'two',
#   'character',
#   'also',
#   'brilliantly',
#   'act',
#   'morgan_freeman',
#   'brad_pitt',
#   'probably',
#   'best',
#   'performance',
#   'one',
#   'odd',
#   'flaw',
#   'half',
#   'way',
#   'found',
#   'learn',
#   'expect',
#   'unexpected',
#   'meant',
#   'rest',
#   'predictable',
#   'bizarre',
#   'way',
#   'simply',
#   'decide',
#   'expect',
#   'move',
#   'expect',
#   'unexpected',
#   'move',
#   'instead',
#   'obvious',
#   'instance',
#   'finale',
#   'guess',
#   'least',
#   'minute',
#   'ahead',
#   'time',
#   'normally',
#   'formula',
#   'disaster',
#   'fortunately',
#   'high',
#   'quality',
#   'make',
#   'twist',
#   'edge',
#   'seat',
#   'suspenseful',
#   'wait',
#   'game',
#   'watch',
#   'horror',
#   'one',
#   'cop',
#   'encounter',
#   'insanity',
#   'pure',
#   'evil',
#   'want',
#   'admire',
#   'honest',
#   'dislike',
#   'brad_pitt',
#   'something',
#   'fierce',
#   'afraid',
#   'must',
#   'professionally',
#   'make',
#   'delivers',
#   'promise',
#   'suspense',
#   'way'],
#  ['somerset',
#   'morgan_freeman',
#   'deeply',
#   'intellectual',
#   'detective',
#   'barely',
#   'week',
#   'left',
#   'retirement',
#   'mill',
#   'brad_pitt',
#   'new',
#   'cop',
#   'town',
#   'pretty',
#   'weak',
#   'detective',
#   'thrown',
#   'together',
#   'investigate',
#   'first',
#   'appear',
#   'another',
#   'homicide',
#   'second',
#   'victim',
#   'found',
#   'somerset',
#   'realises',
#   'open',
#   'shut',
#   'case',
#   'request',
#   'relieve',
#   'light',
#   'impend',
#   'retirement',
#   'mill',
#   'gladly',
#   'take',
#   'case',
#   'plunge',
#   'way',
#   'head',
#   'work',
#   'crimally',
#   'insane',
#   'genius',
#   'continue',
#   'mill',
#   'grows',
#   'erratic',
#   'somerset',
#   'simply',
#   'remain',
#   'guide',
#   'young',
#   'partner',
#   'case',
#   'ultimately',
#   'lead',
#   'one',
#   'fine',
#   'climax',
#   'history',
#   'wonderful',
#   'performance',
#   'freeman',
#   'pitt',
#   'really',
#   'dark',
#   'morbid',
#   'direction',
#   'david',
#   'fincher',
#   'crammed',
#   'suspense',
#   'intrigue',
#   'excitement',
#   'favourite',
#   'scene',
#   'john_doe',
#   'kevin_spacey',
#   'tear',
#   'mill',
#   'car',
#   'drive',
#   'towards',
#   'climax',
#   'act',
#   'simply',
#   'perfect',
#   'pitt',
#   'character',
#   'torn',
#   'apart',
#   'genius',
#   'criminally',
#   'insane',
#   'freeman',
#   'interjects',
#   'insightful',
#   'rationality',
#   'demonstrate',
#   'superior',
#   'mind',
#   'scene',
#   'carry',
#   'intensity',
#   'time',
#   'encapsulates',
#   'primary',
#   'character',
#   'basic',
#   'element',
#   'actor',
#   'achieve',
#   'level',
#   'character',
#   'depth',
#   'three',
#   'fine',
#   'actor',
#   'time'],
#  ['day',
#   'retirement',
#   'detective',
#   'somerset',
#   'team',
#   'new',
#   'city',
#   'detective',
#   'mill',
#   'investigate',
#   'murder',
#   'quickly',
#   'becomes',
#   'series',
#   'somerset',
#   'realises',
#   'killer',
#   'must',
#   'smart',
#   'use',
#   'classic',
#   'literature',
#   'model',
#   'killing',
#   'seven_deadly_sin',
#   'however',
#   'mill',
#   'find',
#   'hard',
#   'see',
#   'anything',
#   'crazy',
#   'man',
#   'killer',
#   'close',
#   'complete',
#   'work',
#   'mill',
#   'somerset',
#   'begin',
#   'close',
#   'however',
#   'nothing',
#   'seem',
#   'dark',
#   'depress',
#   'city',
#   'full',
#   'moral',
#   'degradation',
#   'apathy',
#   'david',
#   'fincher',
#   'come',
#   'onto',
#   'scene',
#   'debut',
#   'feature',
#   'alien',
#   'world',
#   'pause',
#   'scorn',
#   'fit',
#   'alien',
#   'franchise',
#   'yes',
#   'great',
#   'love',
#   'sense',
#   'mood',
#   'dark',
#   'tension',
#   'shadow',
#   'fincher',
#   'create',
#   'year',
#   'later',
#   'see',
#   'fight_club',
#   'game',
#   'people',
#   'get',
#   'fincher',
#   'see',
#   'major',
#   'break',
#   'dark',
#   'vision',
#   'also',
#   'reaped',
#   'box',
#   'office',
#   'gold',
#   'story',
#   'sound',
#   'like',
#   'much',
#   'mismatch',
#   'partner',
#   'one',
#   'young',
#   'cocky',
#   'reckless',
#   'day',
#   'retirement',
#   'go',
#   'serial',
#   'killer',
#   'carry',
#   'series',
#   'twist',
#   'murder',
#   'sound',
#   'like',
#   'lethal',
#   'weapon',
#   'meet',
#   'straight',
#   'video',
#   'thriller',
#   'happily',
#   'rise',
#   'much',
#   'unbelievable',
#   'certainly',
#   'show',
#   'story',
#   'put',
#   'good',
#   'hand',
#   'work',
#   'start',
#   'entombed',
#   'mood',
#   'city',
#   'always',
#   'rain',
#   'uncaring',
#   'people',
#   'etc',
#   'begin',
#   'find',
#   'murder',
#   'fincher',
#   'show',
#   'murder',
#   'let',
#   'see',
#   'aftermath',
#   'shadow',
#   'let',
#   'imagine',
#   'rest',
#   'genius',
#   'see',
#   'gory',
#   'meanwhile',
#   'tension',
#   'cranked',
#   'fever',
#   'pitch',
#   'race',
#   'catch',
#   'killer',
#   'accelerate',
#   'meet',
#   'killer',
#   'get',
#   'well',
#   'right',
#   'end',
#   'simply',
#   'one',
#   'logical',
#   'emotional',
#   'grip',
#   'ending',
#   'ever',
#   'see',
#   'promise',
#   'leave',
#   'cinema',
#   'shell',
#   'shock',
#   'freeman',
#   'excellent',
#   'somerset',
#   'good',
#   'role',
#   'try',
#   'kiss',
#   'girl',
#   'etc',
#   'perfect',
#   'foil',
#   'mill',
#   'killer',
#   'brad_pitt',
#   'also',
#   'superb',
#   'allow',
#   'trade',
#   'look',
#   'well',
#   'little',
#   'opportunity',
#   'pander',
#   'female',
#   'fan',
#   'spends',
#   'lot',
#   'look',
#   'beaten',
#   'paltrow',
#   'ok',
#   'really',
#   'focus',
#   'female',
#   'role',
#   'lee',
#   'ermey',
#   'good',
#   'ever',
#   'sign',
#   'good',
#   'cast',
#   'actor',
#   'stature',
#   'charles',
#   'dutton',
#   'john',
#   'mcginley',
#   'basically',
#   'role',
#   'barely',
#   'count',
#   'cameo',
#   'however',
#   'best',
#   'performance',
#   'kevin_spacey',
#   'year',
#   'become',
#   'oscar',
#   'lovie',
#   'stop',
#   'bad',
#   'guy',
#   'dark',
#   'character',
#   'screen',
#   'small',
#   'portion',
#   'dialogue',
#   'superb',
#   'delivers',
#   'faultlessly',
#   'scene',
#   'share',
#   'car',
#   'ride',
#   'mill',
#   'somerset',
#   'literally',
#   'hang',
#   'every',
#   'word',
#   'however',
#   'alongside',
#   'spacey',
#   'fincher',
#   'stand',
#   'triumphant',
#   'dark',
#   'vision',
#   'give',
#   'perfect',
#   'story',
#   'perfect',
#   'actor',
#   'heart',
#   'cop',
#   'thriller',
#   'excellent',
#   'performance',
#   'excellent',
#   'mood',
#   'moral',
#   'lesson',
#   'excellent',
#   'spacey',
#   'make',
#   'quite',
#   'simply',
#   'jaw',
#   'droppingly',
#   'excellent',
#   'thriller'],
#  ['one',
#   'dark',
#   'movie',
#   'constantly',
#   'rain',
#   'wet',
#   'light',
#   'always',
#   'seem',
#   'dim',
#   'appropriately',
#   'enough',
#   'change',
#   'bright',
#   'shimmer',
#   'heat',
#   'end',
#   'kid',
#   'hat',
#   'dark',
#   'movie',
#   'perhaps',
#   'appropriate',
#   'case',
#   'seven',
#   'attempt',
#   'statement',
#   'humanity',
#   'one',
#   'without',
#   'sin',
#   'seven_deadly_sin',
#   'gluttony_greed',
#   'sloth',
#   'pride',
#   'lust',
#   'envy',
#   'wrath',
#   'prime',
#   'example',
#   'people',
#   'commit',
#   'punish',
#   'one',
#   'one',
#   'brutally',
#   'efficiently',
#   'psychopathic',
#   'killer',
#   'detective',
#   'reluctant',
#   'partner',
#   'william',
#   'somerset',
#   'morgan_freeman',
#   'david',
#   'mill',
#   'brad_pitt',
#   'assign',
#   'track',
#   'killer',
#   'needle',
#   'say',
#   'job',
#   'get',
#   'accomplish',
#   'might',
#   'argue',
#   'do',
#   'surprisingly',
#   'argue',
#   'otherwise',
#   'impressed',
#   'pitt',
#   'act',
#   'thought',
#   'freeman',
#   'great',
#   'job',
#   'usual',
#   'villain',
#   'john_doe',
#   'played',
#   'kevin_spacey',
#   'provide',
#   'chill',
#   'performance',
#   'though',
#   'give',
#   'much',
#   'center',
#   'stage',
#   'say',
#   'anthony',
#   'hopkins',
#   'silence_lamb',
#   'fact',
#   'whole',
#   'seem',
#   'hurry',
#   'without',
#   'give',
#   'key',
#   'character',
#   'enough',
#   'time',
#   'build',
#   'emotional',
#   'worth',
#   'particularly',
#   'mill',
#   'wife',
#   'tracy',
#   'gwyneth_paltrow',
#   'end',
#   'seven',
#   'manage',
#   'get',
#   'point',
#   'across',
#   'effectively',
#   'watch',
#   'thought',
#   'bit',
#   'anti',
#   'climatic',
#   'mull',
#   'later',
#   'image',
#   'echo',
#   'strongly',
#   'mind',
#   'one',
#   'disturb',
#   'film',
#   'see'],
#  ['alien',
#   'debacle',
#   'fincher',
#   'prove',
#   'critic',
#   'wrong',
#   'one',
#   'best',
#   'genre',
#   'innovative',
#   'long',
#   'time',
#   'everyone',
#   'know',
#   'story',
#   'waste',
#   'time',
#   'tell',
#   'trend',
#   'set',
#   'dark',
#   'gritty',
#   'look',
#   'opening',
#   'sequence',
#   'still',
#   'see',
#   'copy',
#   'movie',
#   'tv',
#   'series',
#   'today',
#   'everything',
#   'great',
#   'guess',
#   'anything',
#   'weak',
#   'link',
#   'pitt',
#   'grossly',
#   'overshadow',
#   'freeman',
#   'let',
#   'look',
#   'flaw',
#   'really',
#   'script',
#   'intelligent',
#   'uncompromising',
#   'direction',
#   'innovative',
#   'en',
#   'dare',
#   'production',
#   'design',
#   'cinematography',
#   'top',
#   'notch',
#   'fincher',
#   'one',
#   'big',
#   'boy',
#   'tinseltown',
#   'day',
#   'seven',
#   'reason'],
#  ['love',
#   'psychological',
#   'thriller',
#   'one',
#   'best',
#   'see',
#   'morgan_freeman',
#   'elegant',
#   'convincing',
#   'burnt',
#   'cop',
#   'want',
#   'retire',
#   'found',
#   'fascination',
#   'job',
#   'tough',
#   'let',
#   'go',
#   'brad_pitt',
#   'make',
#   'transition',
#   'cocky',
#   'new',
#   'guy',
#   'serious',
#   'cop',
#   'vry',
#   'convincingly',
#   'say',
#   'kevin_spacey',
#   'always',
#   'excellent',
#   'except',
#   'wonder',
#   'name',
#   'appear',
#   'opening',
#   'credit',
#   'look',
#   'three',
#   'time',
#   'gwyneth_paltrow',
#   'pitt',
#   'wife',
#   'fresh',
#   'charm',
#   'ever',
#   'truly',
#   'enjoy',
#   'performance',
#   'main',
#   'cast',
#   'member',
#   'best',
#   'part',
#   'killer',
#   'caught',
#   'suspense',
#   'fact',
#   'may',
#   'begin'],
#  ['two',
#   'cop',
#   'one',
#   'young',
#   'one',
#   'old',
#   'chase',
#   'serial',
#   'killer',
#   'leave',
#   'paper',
#   'trail',
#   'actually',
#   'one',
#   'best',
#   'film',
#   'see',
#   'want',
#   'watch',
#   'one',
#   'reason',
#   'interest',
#   'plot',
#   'plenty',
#   'action',
#   'great',
#   'twist',
#   'also',
#   'horrible',
#   'aftertaste',
#   'like',
#   'spending',
#   'long',
#   'try',
#   'clear',
#   'block',
#   'drain',
#   'hollywood',
#   'far',
#   'long',
#   'glamorise',
#   'crime',
#   'chase',
#   'criminal',
#   'surprising',
#   'see',
#   'maker',
#   'go',
#   'way',
#   'dark',
#   'decrepit',
#   'cold',
#   'world',
#   'everything',
#   'fall',
#   'apart',
#   'unkept',
#   'seem',
#   'deliberate',
#   'policy',
#   'move',
#   'feature',
#   'many',
#   'david',
#   'fincher',
#   'film',
#   'interest',
#   'different',
#   'strangely',
#   'alienate',
#   'depress',
#   'emotion',
#   'want',
#   'wish',
#   'upon',
#   'serial',
#   'killer',
#   'criminal',
#   'leaf',
#   'clue',
#   'nothing',
#   'new',
#   'way',
#   'plot',
#   'develops',
#   'know',
#   'twist',
#   'cut',
#   'half',
#   'thank',
#   'god',
#   'saw',
#   'without',
#   'know',
#   'pay',
#   'although',
#   'knew',
#   'go',
#   'one',
#   'brad_pitt',
#   'never',
#   'convinces',
#   'professional',
#   'type',
#   'seem',
#   'become',
#   'cop',
#   'overnight',
#   'without',
#   'much',
#   'training',
#   'morgan_freeman',
#   'usual',
#   'quiet',
#   'logical',
#   'act',
#   'bought',
#   'fame',
#   'late',
#   'life',
#   'near',
#   'retirement',
#   'thought',
#   'cop',
#   'retire',
#   'movie',
#   'take',
#   'read',
#   'involve',
#   'stuff',
#   'drawn',
#   'grandstand',
#   'finish',
#   'remember',
#   'forever',
#   'see',
#   'longterm',
#   'reflection',
#   'horrible',
#   'world',
#   'horrible',
#   'people',
#   'carry',
#   'horrible',
#   'act',
#   'reason',
#   'self',
#   'gratification',
#   'serial',
#   'killer',
#   'exist',
#   'since',
#   'dawn',
#   'time',
#   'america',
#   'home',
#   'half',
#   'world',
#   'population',
#   'maybe',
#   'last',
#   'chance',
#   'make',
#   'mark',
#   'society',
#   'medium',
#   'spotlight',
#   'prize',
#   'kill',
#   'someone',
#   'interest',
#   'simple'],
#  ['year',
#   'experience',
#   'dull',
#   'formulaic',
#   'cliched',
#   'call',
#   'thriller',
#   'always',
#   'satisfy',
#   'genuinely',
#   'great',
#   'come',
#   'along',
#   'absolutely',
#   'hesitation',
#   'proclaim',
#   'see',
#   'director',
#   'david',
#   'fincher',
#   'achieve',
#   'somewhat',
#   'mixed',
#   'result',
#   'cinematic',
#   'debut',
#   'alien³',
#   'firmly',
#   'proclaim',
#   'place',
#   'one',
#   'promising',
#   'new',
#   'talent',
#   'somewhat',
#   'surprising',
#   'manage',
#   'elude',
#   'long',
#   'since',
#   'want',
#   'see',
#   'last',
#   'week',
#   'manage',
#   'get',
#   'hand',
#   'dvd',
#   'copy',
#   'without',
#   'ado',
#   'invite',
#   'friend',
#   'equal',
#   'partiality',
#   'towards',
#   'good',
#   'thriller',
#   'promise',
#   'one',
#   'best',
#   'decade',
#   'see',
#   'disappoint',
#   'take',
#   'place',
#   'dark',
#   'gritty',
#   'unnamed',
#   'metropolis',
#   'always',
#   'rain',
#   'danger',
#   'loom',
#   'ominously',
#   'every',
#   'alleyway',
#   'reserve',
#   'harden',
#   'detective',
#   'lt',
#   'william',
#   'somerset',
#   'morgan_freeman',
#   'see',
#   'lifetime',
#   'finally',
#   'prepare',
#   'retire',
#   'country',
#   'away',
#   'madness',
#   'city',
#   'replacement',
#   'impulsive',
#   'detective',
#   'david',
#   'mill',
#   'brad_pitt',
#   'transfer',
#   'request',
#   'eager',
#   'make',
#   'mark',
#   'though',
#   'career',
#   'choice',
#   'harm',
#   'wellbeing',
#   'lonely',
#   'vulnerable',
#   'wife',
#   'tracy',
#   'gwyneth_paltrow',
#   'detective',
#   'soon',
#   'drawn',
#   'case',
#   'serial',
#   'killer',
#   'john_doe',
#   'ritualist',
#   'murder',
#   'victim',
#   'accord',
#   'seven_deadly_sin',
#   'gluttony_greed',
#   'sloth',
#   'lust',
#   'pride',
#   'envy',
#   'wrath',
#   'murder',
#   'begin',
#   'pile',
#   'two',
#   'detective',
#   'investigation',
#   'becomes',
#   'obsession',
#   'inevitable',
#   'outcome',
#   'drastically',
#   'change',
#   'life',
#   'throughout',
#   'brad_pitt',
#   'provide',
#   'comic',
#   'relief',
#   'none',
#   'detracts',
#   'horror',
#   'witness',
#   'screen',
#   'david',
#   'fincher',
#   'unique',
#   'visual',
#   'style',
#   'simply',
#   'thrill',
#   'watch',
#   'despite',
#   'thematically',
#   'dark',
#   'tone',
#   'story',
#   'positively',
#   'brimming',
#   'invigorate',
#   'vibrantly',
#   'contrast',
#   'colour',
#   'light',
#   'graphic',
#   'murder',
#   'scene',
#   'appear',
#   'splash',
#   'screen',
#   'eye',
#   'enhance',
#   'feeling',
#   'dread',
#   'repulsion',
#   'accompany',
#   'john_doe',
#   'horrific',
#   'act',
#   'murder',
#   'rich',
#   'highly',
#   'stylise',
#   'use',
#   'colour',
#   'also',
#   'help',
#   'create',
#   'memorable',
#   'atmosphere',
#   'sheer',
#   'forebode',
#   'imagery',
#   'sure',
#   'stay',
#   'many',
#   'year',
#   'come',
#   'see',
#   'abandon',
#   'gritty',
#   'set',
#   'city',
#   'final',
#   'act',
#   'shift',
#   'action',
#   'starkly',
#   'lit',
#   'open',
#   'field',
#   'beside',
#   'trail',
#   'electric',
#   'power',
#   'line',
#   'loses',
#   'none',
#   'potency',
#   'isolation',
#   'climactic',
#   'arena',
#   'seemingly',
#   'leave',
#   'main',
#   'protagonist',
#   'helpless',
#   'vulnerable',
#   'villain',
#   'anonymously',
#   'title',
#   'john_doe',
#   'played',
#   'delightful',
#   'creepiness',
#   'kevin_spacey',
#   'agree',
#   'part',
#   'condition',
#   'remain',
#   'unbilled',
#   'promotion',
#   'opening',
#   'credit',
#   'unlike',
#   'typical',
#   'serial',
#   'killer',
#   'john_doe',
#   'crazy',
#   'impulsive',
#   'stupid',
#   'mad',
#   'man',
#   'something',
#   'rather',
#   'terrify',
#   'intelligent',
#   'patient',
#   'methodical',
#   'one',
#   'particularly',
#   'ghastly',
#   'crime',
#   'keep',
#   'convict',
#   'drug',
#   'dealer',
#   'chain',
#   'bed',
#   'entire',
#   'year',
#   'remove',
#   'hand',
#   'tongue',
#   'regularly',
#   'pay',
#   'rent',
#   'arouse',
#   'suspicion',
#   'john_doe',
#   'entire',
#   'life',
#   'dedicate',
#   'mankind',
#   'obsession',
#   'commit',
#   'sin',
#   'orchestrate',
#   'crime',
#   'wish',
#   'preach',
#   'society',
#   'transgression',
#   'john_doe',
#   'rather',
#   'uniquely',
#   'give',
#   'large',
#   'portion',
#   'final',
#   'half',
#   'hour',
#   'becomes',
#   'character',
#   'come',
#   'know',
#   'well',
#   'oppose',
#   'half',
#   'construct',
#   'serial',
#   'killer',
#   'usually',
#   'turn',
#   'final',
#   'five',
#   'minute',
#   'shot',
#   'hero',
#   'spacey',
#   'good',
#   'role',
#   'though',
#   'help',
#   'feel',
#   'performance',
#   'effective',
#   'familiar',
#   'much',
#   'later',
#   'work',
#   'excite',
#   'scene',
#   'undoubtedly',
#   'hectic',
#   'foot',
#   'chase',
#   'ensues',
#   'john_doe',
#   'arrives',
#   'home',
#   'apartment',
#   'find',
#   'detective',
#   'somerset',
#   'mill',
#   'wait',
#   'patiently',
#   'outside',
#   'door',
#   'however',
#   'climax',
#   'also',
#   'well',
#   'worth',
#   'mention',
#   'though',
#   'many',
#   'interpretation',
#   'float',
#   'around',
#   'view',
#   'final',
#   'two',
#   'victim',
#   'john_doe',
#   'envy',
#   'david',
#   'mill',
#   'wrath',
#   'order',
#   'prevent',
#   'label',
#   'hypocrite',
#   'mill',
#   'suggest',
#   'car',
#   'ride',
#   'doe',
#   'allow',
#   'deadly_sin',
#   'envy',
#   'result',
#   'death',
#   'tracy',
#   'entice',
#   'mill',
#   'shoot',
#   'simultaneously',
#   'become',
#   'sixth',
#   'victim',
#   'prompt',
#   'mill',
#   'commit',
#   'seventh',
#   'sin',
#   'argue',
#   'since',
#   'mill',
#   'die',
#   'perceive',
#   'one',
#   'doe',
#   'victim',
#   'left',
#   'alive',
#   'circumstance',
#   'perhaps',
#   'diabolical',
#   'punishment'],
#  ['david',
#   'fincher',
#   'release',
#   'perfectly',
#   'construct',
#   'modern',
#   'masterpiece',
#   'see',
#   'one',
#   'exhilarate',
#   'experience',
#   'time',
#   'classic',
#   'come',
#   'cop',
#   'detective',
#   'david',
#   'mill',
#   'brad_pitt',
#   'move',
#   'city',
#   'wife',
#   'tracy',
#   'gwyneth_paltrow',
#   'hope',
#   'finally',
#   'settle',
#   'mill',
#   'take',
#   'job',
#   'detective',
#   'lt',
#   'william',
#   'somerset',
#   'morgan_freeman',
#   'old',
#   'cop',
#   'seven',
#   'day',
#   'retirement',
#   'begin',
#   'dedicate',
#   'badge',
#   'put',
#   'together',
#   'case',
#   'obesity',
#   'murder',
#   'man',
#   'force',
#   'eat',
#   'till',
#   'burst',
#   'lead',
#   'another',
#   'murder',
#   'scene',
#   'lawyer',
#   'bleed',
#   'death',
#   'although',
#   'murderer',
#   'actually',
#   'use',
#   'knife',
#   'make',
#   'lawyer',
#   'begin',
#   'mass',
#   'murder',
#   'masterpiece',
#   'craft',
#   'insane',
#   'john_doe',
#   'brilliantly',
#   'played',
#   'kevin_spacey',
#   'whatever',
#   'watch',
#   'see',
#   'hollow',
#   'see',
#   'far',
#   'many',
#   'scene',
#   'study',
#   'civilisation',
#   'present',
#   'civilisation',
#   'evil',
#   'society',
#   'pleasant',
#   'one',
#   'concentrate',
#   'mainly',
#   'cop',
#   'search',
#   'come',
#   'mystery',
#   'part',
#   'find',
#   'killer',
#   'discover',
#   'policeman',
#   'difference',
#   'method',
#   'obvious',
#   'one',
#   'actually',
#   'work',
#   'course',
#   'somerset',
#   'one',
#   'experience',
# ...
#   'people',
#   'believe',
#   'found',
#   'dark',
#   'disturb',
#   'without',
#   'real',
#   'mission',
#   'speak',
#   'usually',
#   'great',
#   'kind',
#   'view',
#   'consistently',
#   'get',
#   'well',
#   'subsequent',
#   'viewing',
#   'however',
#   'hardly',
#   'stand',
#   'say',
#   'fairly',
#   'predictable',
#   'start',
#   'knew',
#   'minute',
#   'early',
#   'wife',
#   'die',
#   'end',
#   'get',
#   'well',
#   'every',
#   'time',
#   'see',
#   'instance',
#   'check',
#   'chinatown',
#   'legitimate',
#   'noir',
#   'thriller',
#   'get',
#   'well',
#   'age',
#   'feature',
#   'outstanding',
#   'performance',
#   'dense',
#   'plot',
#   'whereas',
#   'fairly',
#   'methodical',
#   'plot',
#   'good',
#   'great',
#   'act',
#   'see',
#   'appeal',
#   'hold',
#   'people',
#   'similarly',
#   'sixth',
#   'sense',
#   'figure',
#   'minute',
#   'may',
#   'like'],
#  ['spoiler',
#   'herein',
#   'great',
#   'boon',
#   'dvd',
#   'get',
#   'view',
#   'review',
#   'comment',
#   'creator',
#   'sometimes',
#   'creative',
#   'artist',
#   'poor',
#   'authority',
#   'depth',
#   'art',
#   'interest',
#   'check',
#   'see',
#   'director',
#   'thought',
#   'put',
#   'often',
#   'find',
#   'simply',
#   'work',
#   'intuition',
#   'well',
#   'perform',
#   'artist',
#   'different',
#   'must',
#   'always',
#   'intend',
#   'intend',
#   'specific',
#   'feel',
#   'effect',
#   'simply',
#   'dvd',
#   'commentary',
#   'involves',
#   'actor',
#   'particular',
#   'interest',
#   'dvd',
#   'hear',
#   'pitt',
#   'really',
#   'commits',
#   'deliver',
#   'worry',
#   'prepares',
#   'sublimate',
#   'self',
#   'order',
#   'create',
#   'image',
#   'mind',
#   'hear',
#   'freeman',
#   'arrogant',
#   'demand',
#   'offering',
#   'take',
#   'leave',
#   'style',
#   'act',
#   'call',
#   'intuitive',
#   'really',
#   'explains',
#   'lot',
#   'freeman',
#   'negative',
#   'attractor',
#   'consider',
#   'pitt',
#   'way',
#   'around',
#   'either',
#   'way',
#   'spacey',
#   'one',
#   'connects',
#   'character',
#   'give',
#   'relatively',
#   'simple',
#   'job',
#   'admit',
#   'story',
#   'move',
#   'well',
#   'engage',
#   'shock',
#   'unexpected',
#   'move',
#   'first',
#   'saw',
#   'repeat',
#   'viewing',
#   'substantial',
#   'sloppiness',
#   'get',
#   'way',
#   'remains',
#   'fine',
#   'light',
#   'think',
#   'fight_club',
#   'much',
#   'superior',
#   'one',
#   'hardly',
#   'rate',
#   'celebration'],
#  ['remember',
#   'last',
#   'saw',
#   'full',
#   'crap',
#   'convince',
#   'cast',
#   'story',
#   'anything',
#   'shirt',
#   'week',
#   'brad_pitt',
#   'character',
#   'say',
#   'go',
#   'performance',
#   'fine',
#   'particularly',
#   'freeman',
#   'spacey',
#   'script',
#   'however',
#   'travesty',
#   'first',
#   'consistency',
#   'killing',
#   'completely',
#   'muddle',
#   'first',
#   'five',
#   'murder',
#   'commit',
#   'spacey',
#   'character',
#   'john_doe',
#   'original',
#   'perceives',
#   'sin',
#   'commit',
#   'kill',
#   'ok',
#   'far',
#   'th',
#   'murder',
#   'paltrow',
#   'character',
#   'also',
#   'do',
#   'doe',
#   'sin',
#   'commit',
#   'rather',
#   'sin',
#   'doe',
#   'perceives',
#   'commit',
#   'get',
#   'th',
#   'murder',
#   'do',
#   'pitt',
#   'character',
#   'doe',
#   'sin',
#   'mill',
#   'pitt',
#   'carry',
#   'guess',
#   'link',
#   'envy',
#   'murder',
#   'doe',
#   'mill',
#   'one',
#   'sinner',
#   'deserve',
#   'kill',
#   'sin',
#   'paltrow',
#   'character',
#   'kill',
#   'along',
#   'pitt',
#   'character',
#   'get',
#   'live',
#   'sin',
#   'wrath',
#   'another',
#   'plot',
#   'point',
#   'think',
#   'overlook',
#   'doe',
#   'religious',
#   'lunatic',
#   'present',
#   'murder',
#   'paltrow',
#   'character',
#   'unborn',
#   'child',
#   'surely',
#   'th',
#   'th',
#   'murder',
#   'doe',
#   'aware',
#   'pregnant',
#   'course',
#   'link',
#   'unborn',
#   'child',
#   'deadly_sin',
#   'see',
#   'writer',
#   'problem',
#   'solution',
#   'train',
#   'wreck',
#   'also',
#   'buy',
#   'doe',
#   'actually',
#   'envious',
#   'pitt',
#   'character',
#   'make',
#   'quirky',
#   'plot',
#   'twist',
#   'seem',
#   'inconsistent',
#   'character',
#   'also',
#   'make',
#   'much',
#   'sense',
#   'plot',
#   'perspective',
#   'see',
#   'paragraph',
#   'get',
#   'thing',
#   'yet',
#   'mention',
#   'silly',
#   'title',
#   'constant',
#   'allusion',
#   'somerset',
#   'knife',
#   'knife',
#   'toss',
#   'etc',
#   'turn',
#   'need',
#   'open',
#   'box',
#   'guess',
#   'make',
#   'assumption',
#   'john_doe',
#   'insane',
#   'master',
#   'plan',
#   'might',
#   'make',
#   'sense',
#   'audience',
#   'insane',
#   'plan',
#   'probably',
#   'make',
#   'sense',
#   'think',
#   'plan',
#   'work',
#   'succeed',
#   'effective',
#   'consistent',
#   'somerset',
#   'character',
#   'implies',
#   'tell',
#   'mill',
#   'kill',
#   'doe',
#   'fulfill',
#   'doe',
#   'plan',
#   'give',
#   'way',
#   'much',
#   'credit',
#   'writer',
#   'almost',
#   'credit',
#   'audience',
#   'recently',
#   'saw',
#   'review',
#   'michael',
#   'haneke',
#   'funny',
#   'game',
#   'fall',
#   'psychological',
#   'horror',
#   'thriller',
#   'genre',
#   'see',
#   'much',
#   'affected',
#   'funny',
#   'game',
#   'impressed',
#   'haneke',
#   'vision',
#   'direction',
#   'say',
#   'responsibly',
#   'recommend',
#   'see',
#   'see',
#   'however',
#   'finally',
#   'found',
#   'haneke',
#   'target',
#   'audience',
#   'see',
#   'recommend',
#   'must',
#   'see',
#   'list',
#   'funny',
#   'game',
#   'really',
#   'must',
#   'see'],
#  ['great',
#   'thriller',
#   'time',
#   'right',
#   'next',
#   'silence_lamb',
#   'david',
#   'fincher',
#   'outdone',
#   'show',
#   'story',
#   'simple',
#   'two',
#   'detective',
#   'must',
#   'apprehend',
#   'twist',
#   'serial',
#   'killer',
#   'punishes',
#   'victim',
#   'sin',
#   'come',
#   'across',
#   'soon',
#   'change',
#   'forever',
#   'expert',
#   'story',
#   'teller',
#   'fincher',
#   'build',
#   'non',
#   'stop',
#   'tension',
#   'nearly',
#   'explodes',
#   'end',
#   'morgan_freeman',
#   'brad_pitt',
#   'best',
#   'great',
#   'chemistry',
#   'two',
#   'gwyneth_paltrow',
#   'terrific',
#   'tracy',
#   'end',
#   'one',
#   'shock',
#   'experience',
#   'ever',
#   'first',
#   'time',
#   'saw',
#   'see',
#   'shock',
#   'horrify',
#   'believe',
#   'happen',
#   'end',
#   'shock',
#   'sure',
#   'one',
#   'reason',
#   'good',
#   'final',
#   'line',
#   'somerset',
#   'move',
#   'ernest',
#   'hemingway',
#   'write',
#   'world',
#   'fine',
#   'place',
#   'worth',
#   'fight',
#   'agree',
#   'second',
#   'part'],
#  ['story',
#   'take',
#   'want',
#   'go',
#   'proof',
#   'gruesome',
#   'act',
#   'see',
#   'aftermath',
#   'action',
#   'disturb',
#   'crime',
#   'least',
#   'gruesome',
#   'movie',
#   'pull',
#   'mix',
#   'repulsive',
#   'crime',
#   'psychological',
#   'involvement',
#   'well',
#   'one',
#   'character',
#   'development',
#   'do',
#   'well',
#   'distract',
#   'bury',
#   'personal',
#   'life',
#   'felt',
#   'main',
#   'detective',
#   'character',
#   'little',
#   'unbelievable',
#   'bit',
#   'methodical',
#   'character',
#   'developed',
#   'though',
#   'start',
#   'see',
#   'part',
#   'personality',
#   'element',
#   'level',
#   'play',
#   'field',
#   'criminal',
#   'end',
#   'found',
#   'diabolically',
#   'analytical',
#   'criminal',
#   'chess',
#   'game',
#   'main',
#   'detective',
#   'criminal',
#   'flawless',
#   'get',
#   'criminal',
#   'custody',
#   'way',
#   'ruin'],
#  ['outstanding',
#   'morgan_freeman',
#   'kevin_spacey',
#   'pitch',
#   'perfect',
#   'brad_pitt',
#   'solid',
#   'pitt',
#   'actually',
#   'lot',
#   'success',
#   'outside',
#   'act',
#   'force',
#   'studio',
#   'keep',
#   'original',
#   'end',
#   'force',
#   'shell',
#   'money',
#   'get',
#   'spacey',
#   'fortunate',
#   'two',
#   'element',
#   'central',
#   'greatness',
#   'spacey',
#   'played',
#   'killer',
#   'chillingly',
#   'make',
#   'message',
#   'seem',
#   'unnerve',
#   'perhaps',
#   'correct',
#   'uncompromising',
#   'end',
#   'leaf',
#   'viewer',
#   'shock',
#   'reel',
#   'work',
#   'without',
#   'outside',
#   'obvious',
#   'element',
#   'another',
#   'key',
#   'freeman',
#   'character',
#   'outlook',
#   'life',
#   'affected',
#   'murder',
#   'new',
#   'partner',
#   'key',
#   'subplot',
#   'brings',
#   'weight',
#   'picture',
#   'also',
#   'david',
#   'fincher',
#   'dark',
#   'dreary',
#   'direction',
#   'add',
#   'somewhat',
#   'similar',
#   'way',
#   'ridley',
#   'scott',
#   'dark',
#   'vision',
#   'add',
#   'blade',
#   'runner',
#   'constant',
#   'rain',
#   'nice',
#   'touch',
#   'especially',
#   'ironically',
#   'recedes',
#   'killer',
#   'show',
#   'never',
#   'nine',
#   'inch',
#   'nail',
#   'fan',
#   'dark',
#   'brand',
#   'music',
#   'fit',
#   'well',
#   'evidence',
#   'opening',
#   'credit',
#   'overall',
#   'think',
#   'one',
#   'great',
#   'film',
#   'time',
#   'watch',
#   'handle',
#   'grisly',
#   'image',
#   'like',
#   'unnerve',
#   'ending'],
#  ['far',
#   'fine',
#   'serial',
#   'killer',
#   'time',
#   'script',
#   'beautifully',
#   'pace',
#   'original',
#   'fantastic',
#   'twist',
#   'end',
#   'act',
#   'superb',
#   'everyone',
#   'top',
#   'game',
#   'morgan_freeman',
#   'show',
#   'versatility',
#   'superb',
#   'natural',
#   'ability',
#   'role',
#   'retire',
#   'detective',
#   'somerset',
#   'brad_pitt',
#   'give',
#   'performance',
#   'career',
#   'young',
#   'feisty',
#   'dectective',
#   'mill',
#   'gwyneth_paltrow',
#   'fantastic',
#   'highly',
#   'sympathetic',
#   'care',
#   'character',
#   'wife',
#   'tracy',
#   'course',
#   'spacey',
#   'steal',
#   'show',
#   'compelling',
#   'chill',
#   'john_doe',
#   'entrancingly',
#   'calm',
#   'chill',
#   'performance',
#   'lift',
#   'picture',
#   'many',
#   'other',
#   'genre',
#   'pure',
#   'evil',
#   'glint',
#   'chill',
#   'anthony',
#   'hopkins',
#   'silence_lamb',
#   'believe',
#   'see',
#   'far',
#   'far',
#   'superior',
#   'silence_lamb',
#   'other',
#   'kind',
#   'one',
#   'great',
#   'film',
#   'second',
#   'usual',
#   'suspect',
#   'feel',
#   'constantly',
#   'underrated',
#   'many',
#   'glad',
#   'see',
#   'although',
#   'feel',
#   'worthy',
#   'top',
#   'david',
#   'fincher',
#   'fine',
#   'hour',
#   'director',
#   'drab',
#   'rainy',
#   'surroundings',
#   'add',
#   'superb',
#   'drab',
#   'atmosphere',
#   'drab',
#   'city',
#   'andrew_kevin_walker',
#   'script',
#   'however',
#   'remember',
#   'incredible',
#   'story',
#   'perfectly',
#   'craft',
#   'act',
#   'beautifully',
#   'spacey',
#   'freeman',
#   'pitt',
#   'co',
#   'must',
#   'see',
#   'every',
#   'fan',
#   'great',
#   'movie',
#   'one',
#   'decade',
#   'great'],
#  ['surprised',
#   'list',
#   'top',
#   'get',
#   'much',
#   'praise',
#   'really',
#   'good',
#   'like',
#   'concept',
#   'love',
#   'morgan_freeman',
#   'blew',
#   'like',
#   'character',
#   'mainly',
#   'mill',
#   'interaction',
#   'character',
#   'especially',
#   'script',
#   'mill',
#   'annoy',
#   'overrate',
#   'worthless',
#   'character',
#   'pitt',
#   'play',
#   'make',
#   'bad',
#   'kept',
#   'think',
#   'might',
#   'ok',
#   'mill',
#   'played',
#   'anyone',
#   'well',
#   'pitt',
#   'guess',
#   'want',
#   'play',
#   'lame',
#   'character',
#   'take',
#   'crime',
#   'seriously',
#   'unprofessional',
#   'moron',
#   'detective',
#   'bring',
#   'wife',
#   'scene',
#   'make',
#   'make',
#   'rest',
#   'painfully',
#   'obvious',
#   'appear',
#   'one',
#   'scene',
#   'point',
#   'role',
#   'oh',
#   'yes',
#   'go',
#   'die',
#   'freeman',
#   'spacey',
#   'great',
#   'script',
#   'puddle',
#   'vomit',
#   'still',
#   'manage',
#   'act',
#   'brilliantly',
#   'think',
#   'hat',
#   'script',
#   'hate',
#   'mill',
#   'excessive',
#   'swear',
#   'twist',
#   'pant',
#   'foul',
#   'language',
#   'many',
#   'scene',
#   'do',
#   'without',
#   'viewer',
#   'take',
#   'guy',
#   'seriously',
#   'also',
#   'word',
#   'lose',
#   'impact',
#   'say',
#   'million',
#   'freak',
#   'time',
#   'weak',
#   'interaction',
#   'end',
#   'bad',
#   'conversation',
#   'police',
#   'car',
#   'horribly',
#   'dumb',
#   'make',
#   'want',
#   'shake',
#   'writer',
#   'much',
#   'well',
#   'mill',
#   'weak',
#   'character',
#   'shut',
#   'damn',
#   'mouth',
#   'end',
#   'predictable',
#   'really',
#   'thick',
#   'see',
#   'one',
#   'main',
#   'character',
#   'eventually',
#   'one',
#   'victim',
#   'especially',
#   'get',
#   'see',
#   'wife',
#   'build',
#   'nothing',
#   'tiny',
#   'hope',
#   'something',
#   'grand',
#   'grimy',
#   'since',
#   'spacey',
#   'convince',
#   'do',
#   'go',
#   'puzzle',
#   'study',
#   'follow',
#   'talk',
#   'disappointed',
#   'end',
#   'end',
#   'scene',
#   'one',
#   'big',
#   'anticlimax',
#   'make',
#   'dislike',
#   'mill',
#   'character',
#   'much',
#   'hop',
#   'shoot',
#   'might',
#   'get',
#   'reason',
#   'respect',
#   'character',
#   'care',
#   'end',
#   'good',
#   'end',
#   'strong',
#   'note',
#   'kill',
#   'doe',
#   'nothing',
#   'bit',
#   'gore',
#   'know',
#   'happen',
#   'next',
#   'waste',
#   'time',
#   'basically',
#   'want',
#   'balance',
#   'bit',
#   'give',
#   'really',
#   'think',
#   'deserves',
#   'praise',
#   'get'],
#  ['really',
#   'hold',
#   'much',
#   'hope',
#   'seven',
#   'almost',
#   'year',
#   'old',
#   'one',
#   'frequently',
#   'miss',
#   'usually',
#   'purpose',
#   'show',
#   'television',
#   'always',
#   'thought',
#   'david',
#   'fincher',
#   'painfully',
#   'rat',
#   'best',
#   'director',
#   'generation',
#   'claim',
#   'many',
#   'people',
#   'patently',
#   'untrue',
#   'see',
#   'danny',
#   'boyle',
#   'darren',
#   'aronfsky',
#   'ang',
#   'lee',
#   'premise',
#   'inspire',
#   'optimism',
#   'couple',
#   'mismatch',
#   'police',
#   'partner',
#   'try',
#   'track',
#   'serial',
#   'killer',
#   'motivate',
#   'seven_deadly_sin',
#   'almost',
#   'believe',
#   'go',
#   'watch',
#   'rework',
#   'vincent',
#   'price',
#   'camp',
#   'classic',
#   'horror',
#   'theatre',
#   'blood',
#   'without',
#   'funny',
#   'bit',
#   'go',
#   'low',
#   'expectation',
#   'fincher',
#   'do',
#   'construct',
#   'thriller',
#   'dialogue',
#   'driven',
#   'sense',
#   'portent',
#   'dread',
#   'easy',
#   'perhaps',
#   'easy',
#   'shock',
#   'audience',
#   'gore',
#   'startle',
#   'moment',
#   'instead',
#   'director',
#   'resists',
#   'easy',
#   'temptation',
#   'put',
#   'audience',
#   'shoe',
#   'detective',
#   'somerset',
#   'mill',
#   'rare',
#   'thriller',
#   'audience',
#   'join',
#   'dot',
#   'detective',
#   'greatly',
#   'help',
#   'morgan_freeman',
#   'probably',
#   'hollywood',
#   'effective',
#   'character',
#   'actor',
#   'point',
#   'amazingly',
#   'pitt',
#   'spacey',
#   'hold',
#   'act',
#   'legend',
#   'short',
#   'good',
#   'gloomy',
#   'thriller',
#   'dark',
#   'cinematography',
#   'dark',
#   'subject',
#   'matter',
#   'fact',
#   'much',
#   'understatement',
#   'refresh',
#   'nearly',
#   'year',
#   'first',
#   'hit',
#   'big',
#   'screen',
#   'remains',
#   'director',
#   'david',
#   'fincher',
#   'best',
#   'work'],
#  ['bleak',
#   'gruesome',
#   'brilliant',
#   'word',
#   'come',
#   'mind',
#   'think',
#   'david',
#   'fincher',
#   'see',
#   'lesser',
#   'hand',
#   'concept',
#   'two',
#   'detective',
#   'trail',
#   'serial',
#   'killer',
#   'commit',
#   'stylize',
#   'murder',
#   'base',
#   'seven_deadly_sin',
#   'nothing',
#   'gimmick',
#   'deftly',
#   'craft',
#   'game',
#   'cat',
#   'mouse',
#   'pull',
#   'make',
#   'want',
#   'turn',
#   'away',
#   'say',
#   'call',
#   'exceptionally',
#   'graphic',
#   'imply',
#   'show',
#   'fill',
#   'blank',
#   'spot',
#   'mind',
#   'eye',
#   'far',
#   'effective',
#   'technique',
#   'cheap',
#   'gross',
#   'route',
#   'cast',
#   'excellent',
#   'lead',
#   'inimitable',
#   'morgan_freeman',
#   'believe',
#   'freeman',
#   'get',
#   'oscar',
#   'nod',
#   'cite',
#   'genre',
#   'bias',
#   'think',
#   'silence_lamb',
#   'get',
#   'everything',
#   'kitchen',
#   'sink',
#   'year',
#   'academy',
#   'award',
#   'co',
#   'star',
#   'brad_pitt',
#   'freeman',
#   'hold',
#   'veteran',
#   'two',
#   'exceptional',
#   'chemistry',
#   'killer',
#   'whose',
#   'identity',
#   'reveal',
#   'ruin',
#   'surprise',
#   'may',
#   'see',
#   'brilliant',
#   'brief',
#   'scene',
#   'pleasant',
#   'risk',
#   'spoil',
#   'happy',
#   'end',
#   'filmmaking',
#   'storytelling',
#   'clinic',
#   'one',
#   'hell',
#   'good'],
#  ['regard',
#   'definition',
#   'modern',
#   'thriller',
#   'easy',
#   'see',
#   'easily',
#   'one',
#   'suspenseful',
#   'movie',
#   'ever',
#   'see',
#   'add',
#   'suspense',
#   'straightforward',
#   'yet',
#   'grim',
#   'storyline',
#   'keep',
#   'audience',
#   'interested',
#   'plot',
#   'revolves',
#   'around',
#   'two',
#   'detective',
#   'william',
#   'somerset',
#   'david',
#   'mill',
#   'try',
#   'solve',
#   'mystery',
#   'serial',
#   'killer',
#   'killer',
#   'john_doe',
#   'leaf',
#   'clue',
#   'around',
#   'unknown',
#   'reason',
#   'detective',
#   'somerset',
#   'believe',
#   'killer',
#   'follow',
#   'seven_deadly_sin',
#   'hence',
#   'title',
#   'seven',
#   'see',
#   'lead',
#   'something',
#   'unclear',
#   'eventually',
#   'capture',
#   'reveals',
#   'final',
#   'victim',
#   'david',
#   'wife',
#   'tracy',
#   'thus',
#   'show',
#   'play',
#   'game',
#   'along',
#   'movie',
#   'see',
#   'since',
#   'suspenseful',
#   'also',
#   'quite',
#   'bleak',
#   'admittedly',
#   'put',
#   'time',
#   'still',
#   'great',
#   'definitely',
#   'worth',
#   'watch',
#   'old',
#   'enough',
#   'remember',
#   'rat',
#   'whether',
#   'enjoy',
#   'probably',
#   'find',
#   'interest',
#   'get']]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_words_bigrams)

# Create Corpus
texts = data_words_bigrams

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=8,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=False)

# %%
pprint(lda_model.show_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.011*"see" + 0.011*"make" + 0.010*"one" + 0.007*"seven" + 0.007*"killer" + '
#   '0.007*"end" + 0.007*"film" + 0.007*"fincher" + 0.007*"really" + '
#   '0.006*"mill"'),
#  (1,
#   '0.018*"see" + 0.016*"somerset" + 0.011*"one" + 0.009*"mill" + '
#   '0.008*"fincher" + 0.008*"killer" + 0.007*"detective" + 0.007*"world" + '
#   '0.007*"story" + 0.006*"take"'),
#  (2,
#   '0.013*"see" + 0.011*"murder" + 0.010*"character" + 0.010*"scene" + '
#   '0.009*"make" + 0.009*"mill" + 0.008*"killer" + 0.008*"dark" + 0.007*"two" + '
#   '0.007*"doe"'),
#  (3,
#   '0.014*"see" + 0.011*"one" + 0.008*"killer" + 0.008*"david" + 0.008*"movie" '
#   '+ 0.006*"seven" + 0.005*"somerset" + 0.005*"mill" + 0.005*"end" + '
#   '0.005*"say"'),
#  (4,
#   '0.019*"see" + 0.013*"character" + 0.011*"somerset" + 0.009*"one" + '
#   '0.009*"mill" + 0.008*"doe" + 0.008*"make" + 0.008*"get" + 0.008*"pitt" + '
#   '0.007*"say"'),
#  (5,
#   '0.016*"see" + 0.012*"john_doe" + 0.011*"mill" + 0.008*"somerset" + '
#   '0.007*"one" + 0.007*"detective" + 0.006*"david" + 0.006*"fincher" + '
#   '0.006*"killer" + 0.005*"performance"'),
#  (6,
#   '0.014*"killer" + 0.013*"character" + 0.012*"one" + 0.011*"see" + '
#   '0.011*"make" + 0.009*"get" + 0.009*"end" + 0.009*"way" + 0.008*"like" + '
#   '0.007*"brad_pitt"'),
#  (7,
#   '0.006*"think" + 0.006*"dark" + 0.006*"like" + 0.006*"watch" + 0.006*"see" + '
#   '0.004*"end" + 0.004*"killer" + 0.004*"one" + 0.004*"make" + 0.004*"get"')]

# %%
x=lda_model.show_topics(num_topics=8, num_words=10,formatted=False)
topics_words = [[wd[0] for wd in tp[1]] for tp in x]

topics = []
for words in topics_words:
    topics.append(words)
    
topics
# Out:
# [['see',
#   'make',
#   'one',
#   'seven',
#   'killer',
#   'end',
#   'film',
#   'fincher',
#   'really',
#   'mill'],
#  ['see',
#   'somerset',
#   'one',
#   'mill',
#   'fincher',
#   'killer',
#   'detective',
#   'world',
#   'story',
#   'take'],
#  ['see',
#   'murder',
#   'character',
#   'scene',
#   'make',
#   'mill',
#   'killer',
#   'dark',
#   'two',
#   'doe'],
#  ['see',
#   'one',
#   'killer',
#   'david',
#   'movie',
#   'seven',
#   'somerset',
#   'mill',
#   'end',
#   'say'],
#  ['see',
#   'character',
#   'somerset',
#   'one',
#   'mill',
#   'doe',
#   'make',
#   'get',
#   'pitt',
#   'say'],
#  ['see',
#   'john_doe',
#   'mill',
#   'somerset',
#   'one',
#   'detective',
#   'david',
#   'fincher',
#   'killer',
#   'performance'],
#  ['killer',
#   'character',
#   'one',
#   'see',
#   'make',
#   'get',
#   'end',
#   'way',
#   'like',
#   'brad_pitt'],
#  ['think',
#   'dark',
#   'like',
#   'watch',
#   'see',
#   'end',
#   'killer',
#   'one',
#   'make',
#   'get']]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.556154548666046
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-eacbdc545be3> in <module>
#       3
#       4 # Compute Coherence Score
# ----> 5 coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
#       6 coherence_lda = coherence_model_lda.get_coherence()
#       7 print('\nCoherence Score: ', coherence_lda)
#
# NameError: name 'data_lemmatized' is not defined

# %%
import pyLDAvis
import pyLDAvis.gensim  # don't skip thi

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
